# %% [markdown]
# ### 1. IMPORT LIBERARY ###

# %%
import pandas as pd
import seaborn as sns
from surprise import SVD
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 from surprise import SVD
#
# ModuleNotFoundError: No module named 'surprise'

# %% [markdown]
# ### 2. LOAD DATA SETS USING PANDAS ###

# %%
ratings = pd.read_csv('booksRating.csv')
ratings
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 ratings = pd.read_csv('booksRating.csv')
#       2 ratings
#
# File D:\Anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File D:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File D:\Anaconda\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'booksRating.csv'

# %% [markdown]
# ### 3. CLEAN DATA ###

# %% [markdown]
# ## 3a. Drop not used columns ##
# Book Ratings has multi dimennsional data as it has review summary, review text, category, publisher, author etc.
#
# User interest varies from person to person.
#
# People can like the books from perticular author or from a perticular category or can very depending on the review description.
#
# Trying to recormmend books considering all these part makes the system complex and plotting them with respect to reach other result in high dimention.
#
# So to keep the recommendation simple we are just using the rating of a book, thus we are dropping columns other then title, user and rating.

# %%
ratings.drop(columns=["Id","Price","profileName","review/helpfulness","review/time","review/summary","review/text"],inplace=True)
ratings.rename(columns= {'review/score' : 'rating', 'User_id':'user','Title':'title'}, inplace=True)
ratings
# Out:
#                                   title            user  rating
# 0        Its Only Art If Its Well Hung!   AVCGYZL8FQQTD     4.0
# 1              Dr. Seuss: American Icon  A30TK6U7DNS82R     5.0
# 2              Dr. Seuss: American Icon  A3UH4UZ4RSVO82     5.0
# 3              Dr. Seuss: American Icon  A2MVUWT453QH61     4.0
# 4              Dr. Seuss: American Icon  A22X4XUPKF66MR     4.0
# ...                                 ...             ...     ...
# 2999995             The Idea of History             NaN     4.0
# 2999996             The Idea of History  A1SMUB9ASL5L9Y     4.0
# 2999997             The Idea of History  A2AQMEKZKK5EE4     4.0
# 2999998             The Idea of History  A18SQGYBKS852K     5.0
# 2999999             The Idea of History             NaN     1.0
#
# [3000000 rows x 3 columns]

# %% [markdown]
# ### 3b. FILTER USERS WITH MIN 150 RATINGS ###
# Amazon book review dataset has 3M ratings, and apply SVD on such large dataset led to Memory issue, so decided to use only those users that have given minimum 150 ratings.

# %%
users_Grouped_By_Rating = ratings.groupby('user')['rating']
books_groupby_users_Ratings = pd.DataFrame(users_Grouped_By_Rating.count())

user_list_min_ratings = books_groupby_users_Ratings[books_groupby_users_Ratings['rating'] >= 150].index
ratings =  ratings[ratings['user'].isin(user_list_min_ratings)]
ratings
# Out:
#                                                      title            user  \
# 1                                 Dr. Seuss: American Icon  A30TK6U7DNS82R
# 6                                 Dr. Seuss: American Icon  A14OJS0VWMOSWO
# 59       Rising Sons and Daughters: Life Among Japan's ...  A3NIQK6ZLYEP1L
# 61       Muslim Women's Choices: Religious Belief and S...   ATDE9JYCPI0L1
# 140                      Eyewitness Travel Guide to Europe  A281NPSIMI1C2R
# ...                                                    ...             ...
# 2999949                   Very Bad Deaths: Library Edition     AFVQZQ8PW0L
# 2999960                                            My Life   A9Q28YTLYREO7
# 2999971                                            My Life  A22LX6529JJ166
# 2999979           Old Quebec,: The fortress of New France,  A32ZKBXJJ45BRY
# 2999996                                The Idea of History  A1SMUB9ASL5L9Y
#
#          rating
# 1           5.0
# 6           5.0
# 59          4.0
# 61          2.0
# 140         5.0
# ...         ...
# 2999949     5.0
# 2999960     5.0
# 2999971     5.0
# 2999979     3.0
# 2999996     4.0
#
# [169476 rows x 3 columns]

# %% [markdown]
# ### 3c. Remove the rating that have no titles###

# %%
display(ratings.isna().sum().sort_values())

print('we can observe that there are **"2 Missing Title"** in the data as shown below, Lets remove that row')

print(ratings[ratings['title'].isna()])
# Out:
# user      0
# rating    0
# title     2
# dtype: int64
# we can observe that there are **"2 Missing Title"** in the data as shown below, Lets remove that row
#         title            user  rating
# 1278792   NaN  A21NVBFIEQWDSG     4.0
# 2272114   NaN  A2FNM5JVHZP0IW     5.0

# %%
ratings = ratings.dropna()
display(ratings.isna().sum().sort_values())
print(ratings[ratings['title'].isna()])

print('we can now observe there are **"NO Missing Title"** in the data')
# Out:
# title     0
# user      0
# rating    0
# dtype: int64
# Empty DataFrame
# Columns: [title, user, rating]
# Index: []
# we can now observe there are **"NO Missing Title"** in the data

# %% [markdown]
# ### 4. VISUALIZATION ###

# %%
display(ratings[['rating']].describe().transpose())
# Out:
#            count      mean       std  min  25%  50%  75%  max
# rating  169474.0  4.351493  0.893993  1.0  4.0  5.0  5.0  5.0

# %%
print('Total unique users in the dataset', ratings['user'].nunique())
print('Total unique products in the dataset', ratings['title'].nunique())
# Out:
# Total unique users in the dataset 537
# Total unique products in the dataset 52973

# %%
from surprise.model_selection import RandomizedSearchCV
from surprise.dataset import Dataset
from surprise.reader import Reader
reader = Reader()

params= {
    "n_epochs": [5, 10, 15, 20],
    "lr_all": [0.002, 0.005],
    "reg_all": [0.4, 0.6]
}

ratings_Surprise_Data = Dataset.load_from_df(ratings, reader)

clf = RandomizedSearchCV(SVD, params, n_jobs=-1, measures=['rmse'])
clf.fit(ratings_Surprise_Data)     
print(clf.best_score)
print(clf.best_params)
print(clf.best_estimator)
# Out:
# {'rmse': 0.7767523328561098}
# {'rmse': {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.4}}
# {'rmse': <surprise.prediction_algorithms.matrix_factorization.SVD object at 0x00000116A3B9AC70>}

# %%
svd = clf.best_estimator['rmse']
svd

# %%
from surprise.model_selection import train_test_split
trainset, testset = train_test_split(ratings_Surprise_Data, test_size=.3, random_state=10)
print('**Training and Testing Set Distribution**')
testset
# Out:
# **Training and Testing Set Distribution**
# [('Flying Colours', 'AHHUNTFQGUGX8', 5.0),
#  ('Lilies On The Moon', 'A14OJS0VWMOSWO', 5.0),
#  ('Wildcats Version 3.0: Full Disclosure', 'A1X8VZWTOG8IS6', 4.0),
#  ('The House of Scorta', 'A14OJS0VWMOSWO', 5.0),
#  ('Anything for Billy', 'A2TAPSNKK9AFSQ', 5.0),
#  ('Emma', 'A1D2C0WDCSHUWZ', 5.0),
#  ('Space Cadet', 'A2BZCHIDR5FTYA', 4.0),
#  ('Lord of the Flies', 'AU6DIIDZK2OQM', 5.0),
#  ('Night And Day (Classic Books on Cassettes Collection) [UNABRIDGED]',
#   'A2SI6BNK5SWSMD',
#   3.0),
#  ('Cosmic consciousness;: A study in the evolution of the human mind',
#   'A1RJD10TTI568L',
#   4.0),
#  ('Just One Look', 'A2SI6BNK5SWSMD', 3.0),
#  ('Arcadia: A play', 'A126KX6FVI4T66', 5.0),
#  ('Directors Take Two', 'A26JGAM6GZMM4V', 5.0),
#  ('Motion to Suppress', 'AHUT55E980RDR', 3.0),
#  ('Dune', 'A4FX5YCJA630V', 5.0),
#  ('The Hobbit', 'AAIL33CYCT47J', 5.0),
#  ('The Rise and Fall of the Third Reich', 'ALR35EFI69S5R', 5.0),
#  ('Twenty Thousand Leagues Under the Sea', 'AXVXIWJ6IU6KA', 4.0),
#  ('The Windows of Heaven', 'A3RP1I0SL7091Q', 4.0),
#  ('Return of the King Being the Third Part of The Lord of the Rings',
#   'AQZH7YTWQPOBE',
#   5.0),
#  ('Emporium: Stories', 'A1XJ64FBB2IRGT', 4.0),
#  ('Jane Eyre', 'A2ENIQZX6VJYUM', 5.0),
#  ('INTRODUCTION TO KOLMOGOROV COMPLEXITY AND ITS APPLICATIONS',
#   'A3EQQP0LD4Z375',
#   5.0),
#  ('Couples Gde/ferti-Hc', 'A14OJS0VWMOSWO', 5.0),
#  ('The Murder Room: An Adam Dalgliesh Mystery', 'A2UIXU97JYCPZG', 3.0),
#  ('Heat Wave', 'AFVQZQ8PW0L', 4.0),
#  ("Sharpe's Triumph: Richard Sharpe and the Battle of Assaye, September 1803 (Richard Sharpe Adventure Series)(Library Binding)",
#   'A1IOR3OTTUK3O5',
#   4.0),
#  ('Sonoran Desert Spring', 'AJDYDG7YZY9QL', 5.0),
#  ('Spire', 'A1CHM200OEN65X', 4.0),
#  ('Tell No One', 'A3SN9EF7GTNEU2', 4.0),
#  ('The Uplift War (The Uplift Saga, Book 3)', 'A1X8VZWTOG8IS6', 4.0),
#  ('What is Literature?" and Other Essays', 'A3SOV9HFM5H9T1', 3.0),
#  ('Pride & Prejudice (Classic Library)', 'A3OH101U0CPUC7', 5.0),
#  ('Code Book: The Science of Secrecy from Ancient Egypt to Quantum Cryptography',
#   'A3Q04XXGGED746',
#   4.0),
#  ('The Warlord of Mars', 'A1796BFN7L774T', 5.0),
#  ('Cotton comes to Harlem (A Dell book)', 'A5HVPX1ETWWIV', 5.0),
#  ('Twenty Thousand Leagues Under the Sea', 'A1796BFN7L774T', 4.0),
#  ('The Rainbow Stories', 'AJQ1S39GZBKUG', 5.0),
#  ('The Change in the Weather: People, Weather, and the Science of Climate',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Hard Bop: Jazz and Black Music 1955-1965', 'A1SYLII0808HD6', 5.0),
#  ('The Epic of Gilgamesh (Penguin Audiobooks)', 'A1MJMYLRTZ76ZX', 5.0),
#  ('Rumours of Rain', 'A2FQWV725FGE8S', 5.0),
#  ('Song of Solomon', 'AIWDJ3S85O10Q', 4.0),
#  ("If It Doesn't Go Up, Don't Buy It, 3rd Edition", 'A2CRUEQ9QIOT70', 5.0),
#  ('The Stranger', 'A1LMBM1N4EXS5W', 3.0),
#  ('The Chapel of Bones (Knights Templar)', 'A5GYYHY2KI5CI', 4.0),
#  ('Twenty-seven Bones', 'A2F6N60Z96CAJI', 5.0),
#  ('Orlando. Eine Biographie.', 'A3LKWMM12AF0PU', 5.0),
#  ('Appointment in Samarra', 'AJQ1S39GZBKUG', 5.0),
#  ('The Hobbit or There and Back Again', 'A1D2C0WDCSHUWZ', 5.0),
#  ('Picture of Dorian Grey (Classic Library)', 'A1XTWXIMUCDGQE', 4.0),
#  ('Autobiographies', 'AHD101501WCN1', 4.0),
#  ('Coffee Trader', 'A2C27IQUH9N1Z', 5.0),
#  ('Volpone; or, The fox (Crofts classics)', 'A20EEWWSFMZ1PN', 5.0),
#  ('Selections from Science And Sanity: An Introduction To Non-Aristotelian Systems And General Semantics',
#   'A20EEWWSFMZ1PN',
#   5.0),
#  ('Pride and Prejudice', 'A1RECBDKHVOJMW', 5.0),
#  ("Strange, sudden & unexpected!: True stories from the files of the Smithsonian Institution's Center for Short-lived Phenomena",
#   'A1S3C5OFU508P3',
#   4.0),
#  ('Reach for the Sky; the Story of Douglas Bader, Legless Ace of the Battle of Britain',
#   'A3MV1KKHX51FYT',
#   4.0),
#  ('New Mexico (Portrait of America)', 'A2WSI8HOWHFDOT', 5.0),
#  ('The Tower Treasure (The Hardy Boys, No. 1)', 'ABX7SEE84DMLU', 3.0),
#  ('Deep Change: Discovering the Leader Within (The Jossey-Bass Business & Management Series)',
#   'A26JGAM6GZMM4V',
#   5.0),
#  ('Fireworks: Nine Stories in Various Disguises.', 'A17IW44FV0HUTY', 3.0),
#  ('Endless Light', 'A1G9FX1KV45N41', 5.0),
#  ('The Murder Room (Adam Dalgliesh Mystery Series #12)',
#   'A1G37DFO8MQW0M',
#   5.0),
#  ('Around the World in Eighty Days (Translated by Mercier Lewis)',
#   'A3QVAKVRAH657N',
#   5.0),
#  ('The Short History of a Prince : A Novel (Random House Large Print)',
#   'A30ZPSYOGFJXR6',
#   1.0),
#  ('Fahrenheit 451 (Cascades S.)', 'A16QQ78I8J29PA', 5.0),
#  ('The first sex', 'A2OJW07GQRNJUT', 5.0),
#  ("Cat's cradle (A Dell book)", 'A2N3YAM4K3ATM', 2.0),
#  ('Echo Park (SIGNED)', 'AYT4FJYVCHYLE', 4.0),
#  ('Visions of Jesus: Direct Encounters from the New Testament to Today',
#   'A2VMT89TCSF105',
#   3.0),
#  ('City Secrets: London', 'A2VE83MZF98ITY', 5.0),
#  ("The Valley of Horses (Earth's Children Series)", 'A1IIX764GG3WNZ', 4.0),
#  ('A Wall for San Sebastian', 'A32ZKBXJJ45BRY', 5.0),
#  ('The Last Juror', 'A1F38YS15PWMRQ', 5.0),
#  ('Woken Furies: A Takeshi Kovacs Novel', 'A55MRYPUAX4QU', 4.0),
#  ('Narrative of the Life of Frederick Douglass: An American Slave',
#   'A1GARI2JT6EAWA',
#   5.0),
#  ('Complete Works of William Shakespeare', 'AHD101501WCN1', 5.0),
#  ('Fighting Skills of the Sas', 'A33I4RCFITFXG5', 5.0),
#  ('Lord of the Flies', 'AK7D1BHZOSOL1', 3.0),
#  ('My Cup Runneth Over: The Life of Angelica Cookson Potts',
#   'A3H82LUT1EC655',
#   5.0),
#  ('Silas Marner', 'A1NT7ED5TATUAM', 4.0),
#  ('The Picture of Dorian Gray (Classic Collection (Brilliance Audio))',
#   'A33FA68V0NCM5E',
#   3.0),
#  ("A People's History of the Vietnam War", 'A2YXRT2XIJIO57', 5.0),
#  ('Wife Of Moon', 'AN8C7BGR98HLN', 4.0),
#  ('THE SECRET LIFE OF HUMPHREY BOGART: THE EARLY YEARS (1899-1931).',
#   'A30TK6U7DNS82R',
#   1.0),
#  ('The tragedy of Romeo and Juliet (The Pelican Shakespeare)',
#   'A1D2C0WDCSHUWZ',
#   5.0),
#  ('Who Wrote the Bible?', 'ALN0TTRTLHA4E', 4.0),
#  ('Irresistible Forces (Danielle Steel)', 'A30ZPSYOGFJXR6', 1.0),
#  ('Through Gates of Splendor', 'A2QO08DN1DTEWD', 4.0),
#  ('The Thin Man', 'A3R1E4K7B6RUHP', 3.0),
#  ('The Hobbit', 'A1G9FX1KV45N41', 5.0),
#  ('White Death (SIGNED)', 'A3M174IC0VXOS2', 5.0),
#  ("Batman: A Death in the Family (All Four Collector's Item Issues in One Volume)",
#   'A3K1RVYM3JQZZS',
#   4.0),
#  ('A World Waiting to be Born: Civility Rediscovered', 'A2HQ8RTAJYEUJO', 3.0),
#  ('The doomsters', 'A13O359A2KX7YY', 4.0),
#  ('Frankenstein (Isis Large Print Fiction)', 'A20EEWWSFMZ1PN', 3.0),
#  ('Glory Road', 'A26BWRBPP4V2WF', 2.0),
#  ('The Seven dials mystery,', 'A3K1RVYM3JQZZS', 4.0),
#  ('Fahrenheit 451 (Cascades S.)', 'AHHUNTFQGUGX8', 3.0),
#  ("Typee: A peep at Polynesian life during a four months' residence in a valley of the Marquesas",
#   'A3QZCA4LTTVGAD',
#   5.0),
#  ('The Street of Crocodiles: Writers from the Other Europe',
#   'A1OBNY1WB38LMI',
#   5.0),
#  ('American Vintage : The Rise of American Wine', 'A3V6Z4RCDGRC44', 5.0),
#  ('Postern of Fate', 'A3BIWTN2DA0YY2', 4.0),
#  ("What to Expect When You're Expecting, 3rd Edition", 'A30H2335OM7RD6', 5.0),
#  ('The Golden Bowl', 'A2FTHCGH06O4Y5', 4.0),
#  ('The Scarlet Letter (Courage Unabridged Classics)', 'A5A25SHEUX6ZK', 4.0),
#  ('The U.P. Trail', 'A37XGUQ1VH0XM6', 5.0),
#  ('Spock must die!', 'A1S3C5OFU508P3', 4.0),
#  ('Tale of the Body Thief', 'A1X8VZWTOG8IS6', 3.0),
#  ('Body Check', 'A1CNQTCRQ35IMM', 3.0),
#  ('Of Mice and Men', 'A3RINLIDX74QLP', 5.0),
#  ('Slaughter-House Five', 'A29SHFBU5O9BWO', 5.0),
#  ('The Complete Sherlock Holmes (Volume One)', 'A3MV1KKHX51FYT', 5.0),
#  ("Baseball's Most Wanted II: The Top 10 Book of More Bad Hops, Screwball Players, and Other Oddities",
#   'AJ98YA4Y333BK',
#   2.0),
#  ('A philosophical dictionary;', 'A1NPNGWBVD9AK3', 5.0),
#  ("The Dean's December", 'A2PR6NXG0PA3KY', 2.0),
#  ('King Rat', 'A395QKQZ15GP4F', 5.0),
#  ('Jesus the Son of man: His words and His deeds as told and recorded by those who knew Him',
#   'A281NPSIMI1C2R',
#   4.0),
#  ('Designer Evolution: a Transhumanist Manifesto', 'A14OJS0VWMOSWO', 5.0),
#  ("Moby Dick or the Whale (The World's Classics)", 'A33FA68V0NCM5E', 5.0),
#  ('Z for Zachariah', 'A2TX179XAT5GRP', 5.0),
#  ('Food Politics: How the Food Industry Influences Nutrition and Health (California Studies in Food and Culture)',
#   'A9Q28YTLYREO7',
#   4.0),
#  ('Jane Eyre', 'ABMX8XUNPR3LP', 4.0),
#  ("The tragedy of King Richard III (Heath's English classics)",
#   'A3UDYY6L2NH3JS',
#   5.0),
#  ('That Hideous Strength (Space Trilogy)', 'A2O5RT4RCC4NU2', 4.0),
#  ('Wuthering Heights', 'A3RTNA9THAU2OP', 4.0),
#  ('Nine Coaches Waiting', 'A3R1E4K7B6RUHP', 4.0),
#  ('The Third Man', 'A319KYEIAZ3SON', 4.0),
#  ('Introducing Shakespeare', 'AHD101501WCN1', 4.0),
#  ('A Dictionary of the History of Science', 'AG35NEEFCMQVR', 4.0),
#  ('A Princess of Mars', 'AD4XBTBQYQBT3', 4.0),
#  ('No Human Involved', 'A2W26AAU92CN70', 5.0),
#  ('The Cove(FBI Thriller)', 'AFVQZQ8PW0L', 4.0),
#  ('A New Twist On Tatting: More Than 100 Glorious Designs',
#   'AXSH6O4OP5L4M',
#   2.0),
#  ('Sad Cypress (A Hercule Poirot Mystery)', 'A1VFKMHY42W2O3', 5.0),
#  ('An Incident at Bloodtide', 'A1BXA3SM3AJOKL', 3.0),
#  ('FROM A BUICK 8 (True first edition)', 'A395QKQZ15GP4F', 4.0),
#  ('While the Gods Play: Shaiva Oracles and Predictions on the Cycles of History and the Destiny of Mankind',
#   'A37XGUQ1VH0XM6',
#   5.0),
#  ('The Third Reich in Power, 1933-1939', 'A20HMA36ESANHC', 4.0),
#  ('The art of cross-examination', 'A2UTKYA2U8542F', 5.0),
#  ('The Picture of Dorian Gray', 'A3EOHYIHQM3KK', 5.0),
#  ('Shadows of Ecstasy', 'A1F8GH7CR68P59', 3.0),
#  ('Wasp Farm', 'A2VMT89TCSF105', 5.0),
#  ('No Name (Penguin Classics)', 'A29NUB3P6YIWZG', 4.0),
#  ('The Captain of All Pleasures', 'AN0XWUHSHRUG6', 4.0),
#  ('The Old Man and the Sea', 'ALDRY40BPNY09', 5.0),
#  ('VOODOO RIVER.', 'A2EENLV6OQ3DYM', 3.0),
#  ('Bound for Glory', 'A1U8DHSI18EEJ1', 5.0),
#  ('The Woman Next Door', 'A3FJOQ23K5PQB8', 4.0),
#  ('Lavengro, (Riverside bookshelf)', 'A1N1YEMTI9DJ86', 4.0),
#  ('Felix Holt the Radical', 'A1G37DFO8MQW0M', 5.0),
#  ('THE MALTESE FALCON - A Sam Spade Mystery', 'A32VWSQ0FPZKZ3', 4.0),
#  ('Indian Music (Oxford Topics in Music)', 'A4H4KYSM2KQ85', 4.0),
#  ('101 Ways to Romance (Hay House Lifestyles)', 'A281NPSIMI1C2R', 5.0),
#  ('Jonathan Livingston Seagull', 'AXQ8T2D9IT6UG', 4.0),
#  ('Crisis of the Negro Intellectual', 'A2OJW07GQRNJUT', 5.0),
#  ('D.N.Angel, Vol. 1', 'A1D2C0WDCSHUWZ', 4.0),
#  ('Emma (Letras Universales / Universal Writings) (Spanish Edition)',
#   'A22DUZU3XVA8HA',
#   5.0),
#  ('Greenmantle,', 'A1MZB6UBKOVSK0', 3.0),
#  ("Who You Were Meant to Be: A Guide to Finding or Recovering Your Life's Purpose",
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Money, Money, Money', 'A680RUE1FDO8B', 5.0),
#  ('Hamlet', 'A370T7ZOJJ76I2', 5.0),
#  ('Nine Princes in Amber', 'A1Y87E22UVYCE6', 5.0),
#  ("The Reader of Gentlemen's Mail: Herbert O. Yardley and the Birth of American Codebreaking",
#   'A1XXJ6I7K2I7SI',
#   5.0),
#  ('1984', 'ARH9IQEMFKR6M', 5.0),
#  ("Chairing the Board: A Practical Guide to Activities & Responsibilities (Effective Directors' Guides)",
#   'A1NATT3PN24QWY',
#   4.0),
#  ('Narrative of Arthur Gordon Pym of Nantucket', 'A1S52XH2CS4Y26', 5.0),
#  ('Chuangtsu: Inner Chapters, a Companion to Tao Te Ching',
#   'A2NTJUI2DLZF4R',
#   5.0),
#  ('Maine: The Dynamics of Political Change', 'A25E44CFFC4B7T', 3.0),
#  ('The Pearl', 'AFYYHRPSFBLWS', 1.0),
#  ('Frankenstein (Isis Large Print Fiction)', 'A3JSRMS7FO6EKQ', 4.0),
#  ('Emma (Radio Collection)', 'A1D2C0WDCSHUWZ', 5.0),
#  ('Catherine the Great', 'A2B9Y0WXNSN17U', 4.0),
#  ('How I Lost 5 Pounds in 6 Years: An Autobiography', 'A1LVMQ52YODRMO', 3.0),
#  ('Silas Marner (audio-CD)', 'A1N1YEMTI9DJ86', 5.0),
#  ('Walden: or, Life in the woods [and] On the duty of civil disobedience',
#   'A3JSRMS7FO6EKQ',
#   5.0),
#  ('Heart of Darkness. (Heritage Club Series)', 'A1LMBM1N4EXS5W', 2.0),
#  ("Red, White, Blue, and Uncle Who?: The Stories Behind Some of America's Patriotic Symbols",
#   'A2NJO6YE954DBH',
#   4.0),
#  ('Their Eyes Were Watching God', 'A303U1MOXG5R1F', 5.0),
#  ('The 100: A ranking of the most influential persons in history',
#   'AHCVWPLA1O4X8',
#   3.0),
#  ('Glory Road', 'A3KF4IP2MUS8QQ', 5.0),
#  ('Harry Potter & the Prisoner of Azkaban', 'A1G9FX1KV45N41', 5.0),
#  ('Chemical Evolution: Molecular Evolution Towards the Origin of Living Systems on the Earth and Elsewhere',
#   'A2OJW07GQRNJUT',
#   5.0),
#  ("One Flew Over the Cuckoo's Nest", 'A370Z6I5GBWU44', 5.0),
#  ('The Given Day', 'A359U0JFFZ0Q04', 4.0),
#  ('The Friendship Factor', 'A1ARA52HB238HT', 4.0),
#  ('The Skinwalkers (The Jim Chee series, Book 4)', 'A20EEWWSFMZ1PN', 5.0),
#  ("Sharpe's Revenge: Richard Sharpe and the Peace of 1814 (Richard Sharpe Adventure Series)(Library Edition)",
#   'A2GBJQ9THOYDAJ',
#   3.0),
#  ('Red Prophet (Tales of Alvin Maker Ser.)', 'A15XY6GGKD3B6D', 4.0),
#  ('Reach for the Sky: The Story of Douglas Bader, Legless Ace of the Battle of Britain',
#   'A3MV1KKHX51FYT',
#   4.0),
#  ("'Four Quartets' Rehearsed: A Commentary on T. S. Eliot's Cycle of Poems",
#   'A1OB5L3WMHJAD9',
#   4.0),
#  ('The Christmas Shoes', 'A3DE9GQDO6O6D1', 5.0),
#  ('Think spiritually', 'A1BMKEJ61X57EU', 4.0),
#  ('Darker Than Night', 'A3RX54RU8R8OMH', 4.0),
#  ('The Doorbell Rang: A Nero Wolfe Novel', 'A17IW44FV0HUTY', 3.0),
#  ('The Golden Compass', 'A21Z8FUB9IZI2L', 5.0),
#  ('How to complete IRS and Labor Department reporting forms for pension, profit sharing and other employee benefit plans',
#   'A1NPNGWBVD9AK3',
#   4.0),
#  ('Eagle or Sun', 'A3QZCA4LTTVGAD', 4.0),
#  ('Getting Together: Building Relationships As We Negotiate',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Fahrenheit 451', 'A2S166WSCFIFP5', 5.0),
#  ('The Mad King', 'A368INKWDUYHMK', 4.0),
#  ('Mythology', 'A359U0JFFZ0Q04', 4.0),
#  ("Tess of the D'urbervilles (Summer Classics)", 'A280GY5UVUS2QH', 5.0),
#  ('The first part of King Henry the Fourth (The Yale Shakespeare)',
#   'A1NT7ED5TATUAM',
#   5.0),
#  ('Travels With Charley, In Search of America', 'A303U1MOXG5R1F', 5.0),
#  ('the Picture of Dorian Gray', 'AI37YX1U4KB1L', 4.0),
#  ('A coffin for King Charles: The trial and execution of Charles I (Time reading program special edition)',
#   'A37GRFP6VMUXKT',
#   4.0),
#  ('Jonathan Strange & Mr. Norrell Signed', 'AC9B29BXXWJHD', 5.0),
#  ('When we were very young', 'A8F2AZWB20X1H', 5.0),
#  ('The Crystal Cave', 'A1X8VZWTOG8IS6', 5.0),
#  ('Knowing Jesus Through the Old Testament.,', 'A11B61QBGHLQDN', 4.0),
#  ('Ceremony', 'A1TIZI060W4BD9', 4.0),
#  ('Soliah: The Sara Jane Olson Story', 'A28GEIVP5KQMZU', 3.0),
#  ('Slaughterhouse-Five', 'AXQ8T2D9IT6UG', 4.0),
#  ('Catch Me If You Can: The Amazing True Story of the Youngest and Most Daring Con Man in the History of Fun and Profit',
#   'A2FEGRJQNU51P9',
#   5.0),
#  ('Blue Highways: A Journey into America', 'A1MC6BFHWY6WC3', 5.0),
#  ('Fortunate Son: A Novel', 'A3OJAWIMUKNHTP', 5.0),
#  ('Memoirs of a Cavalier (Romances and Narratives By Daniel Defoe, Vol 5)',
#   'A12A08OL0TZY0W',
#   2.0),
#  ('Conqueror Fantastic', 'A2GBJQ9THOYDAJ', 3.0),
#  ('Second Coming Attractions', 'A1RAUVCWYHTQI4', 1.0),
#  ('Close to Home : A Novel of Suspense', 'A3BH49ZKESHDID', 4.0),
#  ('Outercourse: The be-dazzling voyage : containing recollections from my Logbook of a radical feminist philosopher (be-ing an account of my time/space travels and ideas--then, again, now, and how)',
#   'A2OJW07GQRNJUT',
#   5.0),
#  ('The Picture of Dorian Gray', 'A1EKTLUL24HDG8', 4.0),
#  ('Silas Marner, the weaver of Raveloe', 'A29NUB3P6YIWZG', 2.0),
#  ('The Godfather', 'AK7D1BHZOSOL1', 5.0),
#  ('The Portable James Joyce', 'A1SYLII0808HD6', 4.0),
#  ('Cosmic consciousness;: A study in the evolution of the human mind',
#   'A2HQ8RTAJYEUJO',
#   4.0),
#  ('Killing Mister Watson', 'A2AYSFGUP5VTY3', 3.0),
#  ('MYTHOLOGY.', 'A2VE83MZF98ITY', 5.0),
#  ('His Witness, Her Child (A Walk Down the Aisle: Wedding Celebration #7) (Harlequin Intrigue Series #618)',
#   'A3NJJZ5NB9LMR3',
#   5.0),
#  ('The Silence of the Lambs', 'A39650P2CZUUC9', 4.0),
#  ('The Rabbit', 'AQ6AGWKWMTY8H', 3.0),
#  ('American English Compendium', 'A14OJS0VWMOSWO', 5.0),
#  ('Reference Guide for Essential Oils', 'A281NPSIMI1C2R', 5.0),
#  ('Fantasy of the 20TH Century', 'A14OJS0VWMOSWO', 5.0),
#  ("Tess of The D'Urbervilles", 'A3SOV9HFM5H9T1', 5.0),
#  ("Aristotle's Metaphysics", 'A3SOV9HFM5H9T1', 3.0),
#  ('Girlz Night Out', 'A2VKWLCNZF4ZVB', 3.0),
#  ("Complete Idiot's Guide to Getting Your Romance Published",
#   'AN0XWUHSHRUG6',
#   5.0),
#  ('Hereditary genius: An inquiry into its laws and consequences',
#   'A3GK6YHJVPSEMM',
#   1.0),
#  ('Circle of Friends', 'AX54G5AL870Q8', 4.0),
#  ("NINE STORIES: A Perfect Day for Bananafish; Uncle Wiggily in Connecticut; Just Before the War with the Eskimos; The Laughing Man; Down at the Dinghy; For Esme - with Love and Squalor; Pretty Mouth and Green My Eyes; De Daumier-Smith's Blue Period; Teddy",
#   'A1K1JW1C5CUSUZ',
#   5.0),
#  ('Woman', 'A39NS429FYXAD1', 2.0),
#  ('Of Mice and Men', 'A33L7G4E8CID3', 5.0),
#  ('The Edge (G K Hall Large Print Book Series)', 'A1CHM200OEN65X', 3.0),
#  ('Over My Dead Body', 'ABX7SEE84DMLU', 4.0),
#  ('Classical Music For Dummies (For Dummies (Lifestyles Paperback))',
#   'A1OX82JPAQLL60',
#   5.0),
#  ('Big Sleep', 'A2V3P1XE33NYC3', 4.0),
#  ('All the Pretty Horses', 'AEGR7IBHUM3R7', 5.0),
#  ('Fahrenheit 451 (Cascades S.)', 'A11M98R135HMSY', 5.0),
#  ('Irving and Muktuk: Two Bad Bears', 'A232HUAELH5J6V', 5.0),
#  ('Tropic of Cancer', 'AI37YX1U4KB1L', 5.0),
#  ('Photographs Annie Leibovitz 1970-1990', 'A1K1JW1C5CUSUZ', 5.0),
#  ('Labyrinth', 'APRY1W9VFEFQ6', 5.0),
#  ('Sense & Sensibility (Classic Library)', 'A368INKWDUYHMK', 5.0),
#  ('Talk Before Sleep', 'A3SN9EF7GTNEU2', 4.0),
#  ('On The Run', 'A370Z6I5GBWU44', 2.0),
#  ('Pride and Prejudice', 'AHXAPVSHPJ6OJ', 4.0),
#  ('The Immoralist', 'A1JH5J1KQAUBMP', 4.0),
#  ('The Picture of Dorian Gray (Classic Collection (Brilliance Audio))',
#   'A1EKTLUL24HDG8',
#   4.0),
#  ('Brave new world,: A novel', 'A20EEWWSFMZ1PN', 5.0),
#  ('The Portable Curmudgeon', 'A1SYLII0808HD6', 5.0),
#  ('Volcano Lover', 'A3SOV9HFM5H9T1', 5.0),
#  ('Free speech in the church', 'A1FDV3WPOHREY9', 5.0),
#  ('Disco for the Departed', 'A2VG0RY3EUWZKB', 5.0),
#  ('Bet Me (Brilliance Audio on Compact Disc)', 'ANOBZWKE25SBY', 5.0),
#  ('Lord of the flies', 'A3IKBHODOTYYHM', 4.0),
#  ('Little women, or, Meg, Jo, Beth, and Amy', 'A1D2C0WDCSHUWZ', 5.0),
#  ("Through Hope and Despair: A Fan's Memories of the Chicago White Sox 1967-1997",
#   'A2O9HU1K7TCF7B',
#   5.0),
#  ('Tough Cookie', 'A3LZGLA88K0LA0', 5.0),
#  ('1984', 'A2SJ11EMIOBLHH', 5.0),
#  ('Portrait of a Killer: Jack the Ripper - Case Closed',
#   'A1BA72K4VK1UN1',
#   5.0),
#  ('Wuthering Heights (New Windmill)', 'A1TKYAYESYHIA2', 5.0),
#  ("Man's Search for Meaning", 'A23ZCJ9U3ZN0FK', 4.0),
#  ('Lysistrata', 'A126KX6FVI4T66', 2.0),
#  ('The Varieties of Religious Experience: A Study in Human Nature (Being the Gifford Lectures on Natural Religion Delivered at Edinburgh in 1901-1902)',
#   'A1I6ZXLKEUKV7W',
#   5.0),
#  ('Beautiful Dreamer', 'A3NJJZ5NB9LMR3', 5.0),
#  ('The Scarlet Letter A Romance', 'ABN5K7K1TM1QA', 5.0),
#  ('the rooster crows a book of american rhymes and jingles',
#   'A3MQXFVZ9DCE8M',
#   4.0),
#  ("High Impact Quotations: Things I Wish I'd Said", 'A14OJS0VWMOSWO', 5.0),
#  ("The psychology of self-esteem;: A new concept of man's psychological nature",
#   'A3EQQP0LD4Z375',
#   3.0),
#  ('Palestinian Refugees: The Right of Return (Pluto Middle Eastern Studies,)',
#   'A2Z4KA3EFQWZOX',
#   3.0),
#  ('The Secret Garden (Worlds Classics)', 'A1MR1VMK999I6O', 5.0),
#  ('RED LEAVES', 'A14OJS0VWMOSWO', 5.0),
#  ('Manhattan Stories From the Heart of a Great City', 'AITIU2DG1MM4A', 5.0),
#  ('Geoffrey Chaucer (Bloomsbury Poetry Classics)', 'A2VE83MZF98ITY', 5.0),
#  ('Great Expectations', 'A1ARA52HB238HT', 4.0),
#  ('The Red Badge of Courage: An Episode of the American Civil War',
#   'A1MC6BFHWY6WC3',
#   5.0),
#  ("Maus II, A Survivor's Tale: And Here My Troubles Began",
#   'A1XTWXIMUCDGQE',
#   5.0),
#  ('Sense & Sensibility Cds (Penguin Classics)', 'A3OH101U0CPUC7', 5.0),
#  ('The Book of the Dead', 'A2F6N60Z96CAJI', 5.0),
#  ('The Thin Man', 'A3MV1KKHX51FYT', 5.0),
#  ('Anastasia, Ask your Analyst', 'A19XE6G6NDZFPS', 3.0),
#  ("Charlotte's Web", 'A2KBF2OYR359AJ', 3.0),
#  ('His Only Desire (Harlequin Intrigue, # 627)', 'A13F2IV3ME23R', 5.0),
#  ('Equal Rites', 'A3KF4IP2MUS8QQ', 3.0),
#  ('At the Altar: Matrimonial Tales', 'A2TXR85WQLE32N', 5.0),
#  ('Governing the hearth: Law and the family in nineteenth-century America (Studies in legal history)',
#   'A2V3P1XE33NYC3',
#   3.0),
#  ('Beautiful Bones Without Hormones', 'A24505CR98NLLV', 5.0),
#  ('Life & Opinions of Tristram Shandy', 'A22DUZU3XVA8HA', 5.0),
#  ('Sin City Volume 1: The Hard Goodbye (3rd Edition)', 'A2S166WSCFIFP5', 5.0),
#  ('The merry wives of Windsor', 'A1N1YEMTI9DJ86', 5.0),
#  ('The First Captain Underpants Collection (Books 1-4)', 'AUM3YMZ0YRJE0', 1.0),
#  ('WAR WITH THE NEWTS', 'AUTBHG6070SL4', 4.0),
#  ('With All Despatch', 'A2O5RT4RCC4NU2', 4.0),
#  ('The Hobbit or There and Back Again', 'A1D2C0WDCSHUWZ', 5.0),
#  ('The Invisible Man', 'A3MV1KKHX51FYT', 4.0),
#  ('The Time Machine: An Invention', 'A3MV1KKHX51FYT', 3.0),
#  ('Mother', 'A30TK6U7DNS82R', 4.0),
#  ('Kim (Modern Library Classics)', 'A2UIXU97JYCPZG', 3.0),
#  ('City', 'AWLFVCT9128JV', 5.0),
#  ('TATOOINE GHOST (STAR WARS)', 'AK7D1BHZOSOL1', 5.0),
#  ('The Talented Mister Ripley', 'A13O359A2KX7YY', 5.0),
#  ('To Kill A Mockingbird', 'A359U0JFFZ0Q04', 5.0),
#  ('The Unhinged World of Glen Baxter: Collected Works (Collected Works (Pomegranate))',
#   'A1S3C5OFU508P3',
#   5.0),
#  ('A Mulligan for Bobby Jobe: A Novel', 'A3LNZKV31R04C4', 5.0),
#  ('Roots of Revolution: An Interpretive History of Modern Iran (Yale Fastback Series)',
#   'A2NHD7LUXVGTD3',
#   4.0),
#  ('Flush', 'A55MRYPUAX4QU', 5.0),
#  ('DEAD ON THE DANCE FLOOR', 'A2CR57GAJKNWVV', 4.0),
#  ('Animal Farm 50TH Anniversary Edition', 'A3OJFPKMCXKOM0', 5.0),
#  ('After The Funeral (Turtleback School & Library Binding Edition) (Hercule Poirot Mysteries (Pb))',
#   'A1HS9F7J51E9CB',
#   4.0),
#  ('The Marvellous Land of Snergs', 'AQZH7YTWQPOBE', 4.0),
#  ('Haunted', 'A3VMCKYN22X0CO', 3.0),
#  ('Presidential Ambition', 'A222LQEPE7O7BV', 3.0),
#  ('The Best of Friends', 'A1BI8PUEHA5CHW', 2.0),
#  ('Johnny Tremain', 'A13G1TKIKHGV3F', 4.0),
#  ('FALLING LEAVES RETURN TO THEIR ROOTS. The True Story of an Unwanted Chinese Daughter.',
#   'AC1K4OQOZ90RS',
#   5.0),
#  ("TESS OF THE D'UBERVILLES (PL 25)", 'A2F540P3L6P5CL', 5.0),
#  ('Brain', 'A2RPIGO3G4M6GN', 5.0),
#  ('The Good German: A Novel', 'AJDYDG7YZY9QL', 5.0),
#  ('The grapes of wrath, (The living library)', 'A2ZATPER188K3J', 5.0),
#  ('American Theocracy: The Peril and Politics of Radical Religion, Oil, and Borrowed Money in the 21stCentury',
#   'A13E0ARAXI6KJW',
#   5.0),
#  ('Death Match', 'A1CDNTB7377YH2', 4.0),
#  ('The lady of Shalott', 'A13G1TKIKHGV3F', 4.0),
#  ('Stanger in a Strange Land', 'A2YUZKPLUYQDKV', 5.0),
#  ('One Lonely Night', 'A1S3C5OFU508P3', 3.0),
#  ('A Museum of Early American Tools', 'A1MC6BFHWY6WC3', 5.0),
#  ('Fast Track Adoption: The Faster, Safer Way to Privately Adopt a Baby',
#   'A3GA09FYFKL4EY',
#   2.0),
#  ('SOLAR LOTTERY.', 'A1AUBGENRIZODO', 4.0),
#  ('The Sea Wolf', 'A3J0OXB9KIC5SS', 4.0),
#  ('Sight-Fishing for Striped Bass : Fly-Fishing Strategies for Inshore, Offshore and the Surf',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Medieval Military Costume: Europa Militaria Special No. 8 (Europa Militaria Special, 8)',
#   'A2L7N2U5Z316ZE',
#   5.0),
#  ('The Fight in the Fields: Cesar Chavez and the Farmworkers Movement',
#   'AMKZHBOK7VMQR',
#   5.0),
#  ('Fables Vol. 3: Storybook Love', 'AUTBHG6070SL4', 4.0),
#  ('Lincoln and His Generals', 'A4QC76NMWE5OC', 4.0),
#  ('Violations (Star Trek Voyager, No 4)', 'A3FHAMLNGHCFU7', 4.0),
#  ('Breach of Promise', 'A2RPIGO3G4M6GN', 2.0),
#  ('Bare Necessity', 'ANOBZWKE25SBY', 4.0),
#  ("Another Woman's Son (Harlequin Superromance No. 1294)",
#   'A13F2IV3ME23R',
#   4.0),
#  ('The World Is Not Enough', 'A1GARI2JT6EAWA', 3.0),
#  ('Three Guineas', 'A2OJW07GQRNJUT', 5.0),
#  ('Starting & Building A Nonprofit: A Practical Guide', 'A14OJS0VWMOSWO', 5.0),
#  ('LAST COYOTE (HARRY BOSCH, NO 4)', 'A25E44CFFC4B7T', 5.0),
#  ('Assembled in Christ: 44 Liturgies with Lay Presiders',
#   'A2UDGZUEYHULS5',
#   2.0),
#  ('Our Man in Havana', 'A3GK9LT41X73NC', 5.0),
#  ('Ball Four', 'A2NJO6YE954DBH', 5.0),
#  ('The World at Night (Isis)', 'A680RUE1FDO8B', 4.0),
#  ('The Sound and the Fury', 'AHD101501WCN1', 5.0),
#  ('ANIMAL FARM - A Fairy Story (Time Reading Program Special Edition)',
#   'A3EJT905S6ZS4K',
#   5.0),
#  ('The Big Sky', 'A37GRFP6VMUXKT', 5.0),
#  ('Magical Thinking: True Stories', 'A328S9RN3U5M68', 5.0),
#  ("Glacier pilot;: The story of Bob Reeve and the flyers who pushed back Alaska's air frontiers,",
#   'A2L7N2U5Z316ZE',
#   5.0),
#  ("Autobiography [of] Edward Gibbon (Everyman's library)",
#   'A2OJW07GQRNJUT',
#   5.0),
#  ('New Faculty: A Practical Guide for Academic Beginners',
#   'A2GBJQ9THOYDAJ',
#   3.0),
#  ('Empire Rising', 'A28WJUJF6D2ULA', 4.0),
#  ('The Miracle Life of Edgar Mint: A Novel', 'A28GEIVP5KQMZU', 5.0),
#  ('Black Sunday', 'A26BWRBPP4V2WF', 4.0),
#  ('To Kill a Mocking Bird', 'ALR35EFI69S5R', 5.0),
#  ('To kill a mockingbird', 'A3FVAWZNKW9GX', 5.0),
#  ('The Strange Case of Dr. Jekyll and Mr. Hyde and Other Stories',
#   'AGHIV0V0ON7MO',
#   3.0),
#  ('Spacetime donuts', 'A17IW44FV0HUTY', 3.0),
#  ('EXPENDABLE.', 'ALN0TTRTLHA4E', 3.0),
#  ('Emerald Sea (The Council Wars)', 'A1I2O9Y3X3HXLS', 5.0),
#  ('The Tragedy of Julius Caesar (The Yale Shakespeare)',
#   'A1VFKMHY42W2O3',
#   5.0),
#  ('The Adventures of Oliver Twist', 'A25KKXUQQ0OLWB', 5.0),
#  ('A Grammar of Christian Faith: Systematic Explorations in Christian Life and Doctrine (2 Volume Set)',
#   'A2VE83MZF98ITY',
#   5.0),
#  ('Leviathan: Or, The matter, forme and power of a commonwealth, ecclesiasticall and civil',
#   'AQQLWCMRNDFGI',
#   5.0),
#  ('Adventures of Huckleberry Finn', 'A1LMBM1N4EXS5W', 5.0),
#  ('The mysterious affair at Styles', 'A3EJWHGO91FA0N', 4.0),
#  ("Big Doc's girl: A novel", 'A15XY6GGKD3B6D', 5.0),
#  ('They Died in Vain: Overlooked, Underappreciated and Forgotten Mystery Novels',
#   'A30TK6U7DNS82R',
#   3.0),
#  ('Daring to Dream (Dream Series)', 'A2E9Q3T876TQ6C', 5.0),
#  ('Murder on the Orient Express', 'A2AYSFGUP5VTY3', 5.0),
#  ('The Bonfire of The Vanities', 'ARH9IQEMFKR6M', 3.0),
#  ('Little Women', 'A8DJ9EU2QP2JM', 4.0),
#  ("Carl Sagan's Cosmic Connection: An Extraterrestrial Perspective",
#   'A1S3C5OFU508P3',
#   5.0),
#  ('Therapeutic Touch As Transpersonal Healing', 'A14OJS0VWMOSWO', 5.0),
#  ('A Tale of Two Cities, Literary Touchstone Edition', 'ABTUNH7645QJL', 5.0),
#  ('Allergies A to Z: Practical Advice on Living With Allergies (Library of Health and Living)',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ("The Scorpion's Gate", 'A3M174IC0VXOS2', 5.0),
#  ('Life of the Mississippi', 'A1EKTLUL24HDG8', 5.0),
#  ('QBVII', 'A395QKQZ15GP4F', 5.0),
#  ("Saint Peter's Fair: The Fourth Chronicle of Brother Cadfael",
#   'A7SSCDSCM4PXF',
#   4.0),
#  ('A Stir of Echoes', 'A1L43KWWR05PCS', 3.0),
#  ('Hondo', 'A3QVAKVRAH657N', 5.0),
#  ('A Man To Call My Own', 'AN0XWUHSHRUG6', 2.0),
#  ('A European Armorial: An Armorial of Knights of the Golden Fleece and 15th Century Europe - From a Contemporary Manuscript',
#   'A2GBJQ9THOYDAJ',
#   4.0),
#  ('A Mirror for Observers', 'AD4XBTBQYQBT3', 5.0),
#  ('The Invisible Man', 'A3EOHYIHQM3KK', 4.0),
#  ("Tess of Th D'Urbervilles (Pbk)(Oop) (Bloom's Notes)",
#   'A3IKBHODOTYYHM',
#   4.0),
#  ('The call of the wild', 'A20EEWWSFMZ1PN', 5.0),
#  ('Catch 22', 'A2O9HU1K7TCF7B', 5.0),
#  ("Rosemary's Baby", 'A2V1121177OVJ', 5.0),
#  ('The Peterkin Papers', 'A3KCMEJTRQHNAP', 5.0),
#  ('Living With Contradiction: Reflections on the Rule of St. Benedict',
#   'A2VE83MZF98ITY',
#   5.0),
#  ('Speaker for the Dead', 'ADY0QI5IENSLY', 5.0),
#  ('Talk Before Sleep', 'A39650P2CZUUC9', 4.0),
#  ('THE SUN ALSO RISES', 'A3QW09WANRS6BZ', 4.0),
#  ("You can't beat God givin': Miracle testimonies from ordinary people serving an extraordinary God",
#   'A1XJOSJN6FHFO0',
#   5.0),
#  ('Endless Chain (Shenandoah Album)', 'AFVQZQ8PW0L', 5.0),
#  ('Nature Lovers', 'A14OJS0VWMOSWO', 5.0),
#  ('The Blue Flower', 'A37F1G84K35FCZ', 5.0),
#  ("Big Girls Don't Cry (Harlequin Superromance No. 1296)", 'AFVQZQ8PW0L', 4.0),
#  ('War and Rememberance', 'A1CDNTB7377YH2', 5.0),
#  ('An inquiry into the nature and causes of the wealth of nations',
#   'A3SOV9HFM5H9T1',
#   5.0),
#  ('The Plague', 'A1OBNY1WB38LMI', 5.0),
#  ('Impossible Things', 'A17IW44FV0HUTY', 5.0),
#  ('Headlong', 'A2W26AAU92CN70', 4.0),
#  ('Persuasion', 'A1D2C0WDCSHUWZ', 5.0),
#  ('Dogs of Riga', 'A2AYSFGUP5VTY3', 4.0),
#  ('A Short History of Financial Euphoria (The Larger Agenda Series)',
#   'A1U8DHSI18EEJ1',
#   4.0),
#  ('When the Emperor Was Divine', 'A4R8GJX3UZ1I', 5.0),
#  ("It's Disgusting and We Ate It! True Food Facts from Around the World and Throughout History",
#   'AIO247KHD2O40',
#   4.0),
#  ('Murder in the Calais coach,', 'A1NC9AGZOBI0M1', 5.0),
#  ('Vengeance: the True Story of an Israeli Counter-terrorist Team',
#   'A2B1GZIRD6W646',
#   5.0),
#  ('Hard Times', 'ASOJUBRHQI1DW', 3.0),
#  ('Brideshead Revisited: The Sacred and Profane Memories of Captain Charles Ryder',
#   'AU6DIIDZK2OQM',
#   4.0),
#  ('The Oregon Trail (Signet classics)', 'A8DJ9EU2QP2JM', 4.0),
#  ('The Eskimo of North Alaska, (Case studies in cultural anthropology)',
#   'A4H4KYSM2KQ85',
#   5.0),
#  ('Whistle me home', 'AU6DIIDZK2OQM', 4.0),
#  ('The monster at the end of this book (A little golden book)',
#   'A3SRPFVPZQV05X',
#   5.0),
#  ('The Rescue', 'A280GY5UVUS2QH', 4.0),
#  ('The Hermit Thrush Sings', 'A2VCGJLKGK2WJJ', 5.0),
#  ('REAL WORLD WEB SERVICES', 'A2QT0KPQU671OU', 4.0),
#  ('Lad: a dog,', 'A1K9IG5MP8RW75', 5.0),
#  ('The Mayor of Casterbridge (Signet Classical Books)', 'A3V2W0GE6XQUPF', 4.0),
#  ('Blueberries for Sal', 'A6HXFDIC7DVTC', 4.0),
#  ('Three Guineas (Shakespeare Head Press Edition of Virginia Woolf)',
#   'A2OJW07GQRNJUT',
#   5.0),
#  ('The charioteer', 'A8F2AZWB20X1H', 5.0),
#  ('Adam Bede (Film/TV tie-in series)', 'A1G37DFO8MQW0M', 5.0),
#  ('Plains Indian Drawings 1865-1935', 'A2L7N2U5Z316ZE', 5.0),
#  ("Sharpe's Battle (Richard Sharpe's Adventure Series #12)",
#   'A29CUCGRX04TS8',
#   2.0),
#  ('Without Remorse', 'A1Z81GM85KH5XS', 3.0),
#  ('A Streetcar Named Desire', 'A32VWSQ0FPZKZ3', 5.0),
#  ('BOY', 'A25ACLV5KPB4W', 5.0),
#  ('Kingdom of the Golden Dragon', 'A3H82LUT1EC655', 5.0),
#  ('Persuasion', 'A1D2C0WDCSHUWZ', 5.0),
#  ('Flatland: A Romance of Many Dimensions', 'A37XGUQ1VH0XM6', 5.0),
#  ('Stanger in a Strange Land', 'ANEDXRFDZDL18', 2.0),
#  ('My Lord John', 'A356TJCTCLDN89', 4.0),
#  ('Rabbit, run.', 'A1T17LMQABMBN5', 5.0),
#  ('A Kiss of Shadows (Meredith Gentry, Book 1)', 'A3H2CKTFZ3B3GD', 3.0),
#  ('Leviticus (New International Commentary on the Old Testament)',
#   'A341BG8RMH8QW',
#   5.0),
#  ('Ruskin (Past Masters)', 'AHD101501WCN1', 5.0),
#  ('The Rise of Silas Lapham', 'AEGR7IBHUM3R7', 5.0),
#  ('National Geographic Atlas of the World', 'A2B21POKQ3N09H', 5.0),
#  ('Sense & Sensibility (Classic Library)', 'AEGR7IBHUM3R7', 5.0),
#  ('Naughty little monkeys', 'A6HXFDIC7DVTC', 3.0),
#  ('The Uplift War (The Uplift Saga, Book 3)', 'A29CUCGRX04TS8', 4.0),
#  ('Everyone But Thee And Me', 'A20EEWWSFMZ1PN', 5.0),
#  ('Pride and Prejudice', 'A3O2RCKAMSE9X7', 5.0),
#  ('The Four Loves', 'AGHIV0V0ON7MO', 5.0),
#  ('Mere Christianity', 'A2QO08DN1DTEWD', 5.0),
#  ('Mystic Warrior (The Bronze Canticles, Book 1)', 'ANEDXRFDZDL18', 1.0),
#  ('The Pattern', 'A30TK6U7DNS82R', 5.0),
#  ('Winterdance', 'A3QS5UYAGHF4IU', 5.0),
#  ('The call of the wild', 'ASOJUBRHQI1DW', 4.0),
#  ('The House on the Beach: Pilgrim Cove (Harlequin Superromance No. 1192)',
#   'A2BZCHIDR5FTYA',
#   5.0),
#  ("Angela's Ashes (Turtleback School & Library Binding Edition)",
#   'A2F3SXHT6RBV81',
#   3.0),
#  ('Stronger than Custom: West Point and the Admission of Women',
#   'A3AUL23GMCOP2A',
#   5.0),
#  ('Amazing Math Puzzles', 'A1S3C5OFU508P3', 4.0),
#  ('The Old Man and the Sea', 'A26BVUB2YJMGB7', 5.0),
#  ('Body Check', 'AFVQZQ8PW0L', 4.0),
#  ('ERAGON: INHERITANCE, BOOK ONE.', 'AMX0PJKV4PPNJ', 2.0),
#  ('Ulysses,', 'A1NT7ED5TATUAM', 4.0),
#  ('Inherit the Wind', 'A2D9IEFJGB483Q', 4.0),
#  ('Smart Choices: A Practical Guide to Making Better Decisions',
#   'A1K1JW1C5CUSUZ',
#   5.0),
#  ('The Catcher in the Rye', 'A3SRPFVPZQV05X', 4.0),
#  ('Hot Springs', 'AR2DE47VCY1C8', 5.0),
#  ('The Tuesday Club Murders', 'A1BA72K4VK1UN1', 4.0),
#  ('Dead Wrong', 'A14OJS0VWMOSWO', 5.0),
#  ('Ghost Fleet: The Sunken Ships of Bikini Atoll', 'A2W7WH9V5OKUA9', 5.0),
#  ("The Mother's Day Garden", 'AFVQZQ8PW0L', 4.0),
#  ('Mother Road', 'A2F6N60Z96CAJI', 4.0),
#  ('Eldest (Inheritance, Book 2)', 'A1D2C0WDCSHUWZ', 1.0),
#  ("Ain't nothin' as sweet as my baby: The story of Hank Williams' lost daughter",
#   'A2F3SXHT6RBV81',
#   3.0),
#  ("Wait for Love: A Black Girl's Story", 'A2VKWLCNZF4ZVB', 4.0),
#  ('Late Great Planet Earth', 'A3GK6YHJVPSEMM', 1.0),
#  ('The Murder of Roger Ackroyd', 'A2AYSFGUP5VTY3', 4.0),
#  ('Prince Caspian : The Return to Narnia', 'A1X4JO8EJ1U5BR', 4.0),
#  ('Coningsby or the New Generation', 'A32ZKBXJJ45BRY', 4.0),
#  ('City (Perma Star 264)', 'A2YUZKPLUYQDKV', 5.0),
#  ('The Illuminator', 'A1L43KWWR05PCS', 4.0),
#  ('Domestic manners of the Americans, (The unit books)',
#   'A2PR6NXG0PA3KY',
#   5.0),
#  ('Slaughter-House Five', 'A2UTKYA2U8542F', 5.0),
#  ('To Kill A Mockingbird', 'ARD5I31J12UU8', 3.0),
#  ('Anne of the Island', 'A2NJO6YE954DBH', 5.0),
#  ('Feathered Dragons: Studies on the Transition from Dinosaurs to Birds (Life of the Past)',
#   'A2F3SXHT6RBV81',
#   4.0),
#  ('Upstate', 'A2TX179XAT5GRP', 5.0),
#  ('VANISHING ACT (JANE WHITEFIELD, NO 1)', 'A3BH49ZKESHDID', 3.0),
#  ('The problems of philosophy (Home university library of modern knowledge)',
#   'AHD101501WCN1',
#   5.0),
#  ('The Abolition of Man', 'A96K1ZGW56S2I', 5.0),
#  ('Family Life', 'A30ZPSYOGFJXR6', 3.0),
#  ("Levi's Will", 'A1IOJE0W1NXOSE', 5.0),
#  ('Presidential Anecdotes', 'A2VD3CYOEMJ6SR', 4.0),
#  ('The Complete Diving Guide: The Caribbean (Vol. 1) Dominica, Martinique, St. Lucia, St Vincent & The Grenadines, Grenada, Tobago, Barbados',
#   'A2W7WH9V5OKUA9',
#   5.0),
#  ('Arrowsmith (Signet Classics)', 'A1LMBM1N4EXS5W', 3.0),
#  ("John Stanley's Creature Features Strikes Again Movie Guide",
#   'A328S9RN3U5M68',
#   5.0),
#  ('Manhattan Stories From the Heart of a Great City', 'A2NHD7LUXVGTD3', 5.0),
#  ('Mademoiselle de Scuderi (Hesperus Classics)', 'A2V3P1XE33NYC3', 4.0),
#  ('A kind of anger', 'A13O359A2KX7YY', 4.0),
#  ('Under the Banner of Heaven: A Story of Violent Faith',
#   'A2NHD7LUXVGTD3',
#   4.0),
#  ('The Day Before Sunrise A Novel', 'A222LQEPE7O7BV', 5.0),
#  ('THE MEMBER OF THE WEDDING', 'A1L43KWWR05PCS', 4.0),
#  ('Mere Christianity', 'AGHIV0V0ON7MO', 5.0),
#  ('Farewell, my lovely', 'A11M98R135HMSY', 4.0),
#  ('Cheerfulness Breaks in', 'A30TK6U7DNS82R', 4.0),
#  ('The confessions of St. Augustine (Universal library)',
#   'A36K2N527TXXJN',
#   5.0),
#  ('A Sudden Change of Heart', 'A3DE9GQDO6O6D1', 1.0),
#  ('Under Western Eyes (Malay edition)', 'A2PR6NXG0PA3KY', 5.0),
#  ('Mary Stuart', 'A3NH7PYU4AD5GA', 5.0),
#  ("All the King's Men", 'AAIL33CYCT47J', 5.0),
#  ('Perelandra, a novel', 'AGHIV0V0ON7MO', 4.0),
#  ('Crime and Punishment', 'A3OEECMCM2T4KQ', 5.0),
#  ('The Book on Leadership', 'A2BZCHIDR5FTYA', 5.0),
#  ('Sometimes I Live in the Country (Plume)', 'A2CW9IQAPFEYLM', 5.0),
#  ('Desolation Island (Master and Commander Series)', 'A3J0OXB9KIC5SS', 3.0),
#  ('Dead Tide', 'AFVQZQ8PW0L', 5.0),
#  ('Claudius, the god and his wife Messalina', 'A2F079BGQTQ3BM', 3.0),
#  ('Gramercy Park (Beeler Large Print Series)', 'A3M174IC0VXOS2', 5.0),
#  ("Girls' Poker Night: A Novel of High Stakes", 'A1K9IG5MP8RW75', 3.0),
#  ('The Forsythe Saga', 'A146H6A41B26QT', 5.0),
#  ('The Hobbit There and Back Again', 'A1D2C0WDCSHUWZ', 5.0),
#  ('What Maisie Knew', 'A8IPQ1Q1O7YX5', 4.0),
#  ('The Murder of Roger Ackroyd', 'A2O9HU1K7TCF7B', 5.0),
#  ('Fathers & sons,', 'A1NPNGWBVD9AK3', 5.0),
#  ('Song of the Exile', 'A17FLA8HQOFVIG', 4.0),
#  ('Black Notice (Random House Large Print)', 'A2E9Q3T876TQ6C', 3.0),
#  ('Jane Eyre', 'A1PKJUAQFGNLSX', 5.0),
#  ('Trucks', 'AEKWD5WIFP6', 3.0),
#  ('The Werewolf of Paris', 'A1Z81GM85KH5XS', 4.0),
#  ('A Study in Scarlet', 'A319KYEIAZ3SON', 4.0),
#  ('Daniel Deronda (Everymans Library)', 'AU7ND6NOCX9IA', 5.0),
#  ('Tarzan of the Apes', 'AWLFVCT9128JV', 3.0),
#  ('The Collected Beowulf', 'A2EDZH51XHFA9B', 3.0),
#  ('Strawberry Girl', 'A43P0V05RM3SR', 5.0),
#  ('Tender Is the Night', 'A3R8PXSFGY9MC2', 4.0),
#  ("The Optimist's Daughter", 'A2YF4ZMECJVLK9', 4.0),
#  ('Cosmopolitanism: Ethics in a World of Strangers (Issues of Our Time Series)',
#   'A16QODENBJVUI1',
#   5.0),
#  ('STOLEN LIVES', 'A1BI8PUEHA5CHW', 5.0),
#  ('Aftermath', 'A2GBJQ9THOYDAJ', 5.0),
#  ('The Fifth Victim', 'A33I4RCFITFXG5', 5.0),
#  ('The blue mustang', 'A3N8RZSXKN1OR2', 3.0),
#  ('A MAN CALLED PETER', 'A1BMKEJ61X57EU', 5.0),
#  ('Blues Lessons: A Novel', 'A7SSCDSCM4PXF', 4.0),
#  ('Emma (CH) (Jane Austen Collection)', 'A1D2C0WDCSHUWZ', 5.0),
#  ('The Picture of Dorian Gray (Penguin Classics)', 'ABMX8XUNPR3LP', 4.0),
#  ('Black Beauty: His Grooms and Companions. Second Frank Miller Edition.',
#   'A4FX5YCJA630V',
#   5.0),
#  ('The Hobbitt, or there and back again; illustrated by the author.',
#   'A2C27IQUH9N1Z',
#   5.0),
#  ('Whose body?: A Lord Peter Wimsey novel', 'A20EEWWSFMZ1PN', 5.0),
#  ('The Screwtape letters,', 'A1LMBM1N4EXS5W', 5.0),
#  ('Antonio', 'A1S3C5OFU508P3', 5.0),
#  ('The annotated Jules Verne, Twenty thousand leagues under the sea',
#   'A1D2C0WDCSHUWZ',
#   5.0),
#  ('A Matter of Interpretation', 'A1OX82JPAQLL60', 5.0),
#  ('Blood Sisters: Lesbian Vampire Tales', 'A3NIQK6ZLYEP1L', 4.0),
#  ('Skinny Dip', 'ABWF7YVZAU1QP', 3.0),
#  ('The Cat I.Q. Test', 'A1OX82JPAQLL60', 5.0),
#  ('Loire, 3rd (Country & Regional Guides - Cadogan)', 'A3NLJZI5NEOT0K', 5.0),
#  ("Catchin' the Drift O' the Draft", 'A14OJS0VWMOSWO', 5.0),
#  ("First Contact: A Reader's Selection of Science Fiction and Fantasy",
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Heart of Darkness', 'AD0J5KK4WQXNS', 2.0),
#  ('Brave New World', 'A2L7N2U5Z316ZE', 5.0),
#  ('England under the Stuarts (A History of England)', 'A2AYSFGUP5VTY3', 4.0),
#  ('Do Everything in the Dark: A Novel', 'AYT4FJYVCHYLE', 3.0),
#  ('A Dazzle of Dragonflies', 'A2VMT89TCSF105', 3.0),
#  ("A Tolkien Compass: Including J. R. R. Tolkien's Guide to the Names in The Lord of the Rings",
#   'A3MSB482DIB9SL',
#   5.0),
#  ('Out of Africa ( 1st/1st )', 'AHD101501WCN1', 5.0),
#  ("One Flew Over the Cuckoo's Nest", 'AJQ1S39GZBKUG', 5.0),
#  ('The Plymouth Thanksgiving,', 'A2FS9CYCWC6HLW', 3.0),
#  ('Visitor', 'A25E44CFFC4B7T', 5.0),
#  ('Antarctica', 'A37F1G84K35FCZ', 4.0),
#  ('Creative Projects with LEGO Mindstorms', 'A4H4KYSM2KQ85', 5.0),
#  ("A Connecticut Yankee in King Arthur's Court", 'A1LMBM1N4EXS5W', 5.0),
#  ('Animal Dreams', 'A2CRUEQ9QIOT70', 5.0),
#  ('The Year of the Quiet Sun', 'A1Z81GM85KH5XS', 3.0),
#  ('The Lion, The witch and the Wardrobe', 'A1V8NBMG0PDVK1', 4.0),
#  ('Blue Skies', 'A33I4RCFITFXG5', 5.0),
#  ('Northanger Abbey: A novel (The select library of fiction)',
#   'A3EJWHGO91FA0N',
#   5.0),
#  ('Cranford', 'A34UTL4AVX80MK', 4.0),
#  ("Moby Dick or The White Whale (Harper's Modern Classics)",
#   'AKT8TGIT6VVZ5',
#   5.0),
#  ('Earthcore', 'ABWF7YVZAU1QP', 3.0),
#  ('Red Sky at Morning', 'A2AIE9DO5QSVBD', 5.0),
#  ('A Painted house: A novel (The Oxford American)', 'A1K1JW1C5CUSUZ', 3.0),
#  ('In This Mountain (The Mitford Years, Book 7)', 'A1OX82JPAQLL60', 5.0),
#  ('My Utmost for His Highest: Selections for the Year- The Golden Book of Oswald Chambers',
#   'A3FVAWZNKW9GX',
#   5.0),
#  ('The Conspiracy Club', 'A2F3M93RRLFQNJ', 3.0),
#  ('LEAVE IT TO PSMITH', 'AWLFVCT9128JV', 5.0),
#  ('Lord of the flies: A novel', 'A1I6ZXLKEUKV7W', 5.0),
#  ('Leaving Home - A Collection Of Lake Wobegon Stories',
#   'A1OX82JPAQLL60',
#   5.0),
#  ('The Master Sniper', 'A14OJS0VWMOSWO', 5.0),
#  ('Moby Dick;: Or, The whale,', 'A22DUZU3XVA8HA', 5.0),
#  ('The Red Badge of Courage: An Episode of the American Civil War',
#   'A2HFQ405AKX4IW',
#   4.0),
#  ('Animal Farm 50TH Anniversary Edition', 'A20EEWWSFMZ1PN', 5.0),
#  ('Pride and Prejudice', 'A3OH101U0CPUC7', 5.0),
#  ('Christmas in Plains Signed', 'A2FS9CYCWC6HLW', 4.0),
#  ('The Gabriel Hounds', 'A3R1E4K7B6RUHP', 4.0),
#  ('The Catcher in the Rye [Audiobook] [Cd] [Unabridged] (Audio CD)',
#   'A18IK6YI6T3RK2',
#   5.0),
#  ('The Schirmer Inheritance', 'A13O359A2KX7YY', 4.0),
#  ('Middlesex', 'A3LKWMM12AF0PU', 5.0),
#  ('Bright Lights, Big City', 'AIWDJ3S85O10Q', 4.0),
#  ('The Island Of Dr.Moreau', 'A16QODENBJVUI1', 3.0),
#  ('Stone Quarry', 'ABWF7YVZAU1QP', 4.0),
#  ('AN Apology for Raymond Sebond (Penguin Classics)', 'A3SOV9HFM5H9T1', 3.0),
#  ("Writer's Guide to Book Editors, Publishers, and Literary Agents, 2002-2003 (with CD-ROM): Who They Are! What They Want! And How to Win Them Over!",
#   'A356TJCTCLDN89',
#   3.0),
#  ("Everything's Eventual: 14 Dark Tales", 'A1HS9F7J51E9CB', 5.0),
#  ('The Legend', 'A2FQWV725FGE8S', 3.0),
#  ('That Hideous Strength: A Modern Fairy-Tale for Grown-ups',
#   'A34PCCROYXQM77',
#   4.0),
#  ("Here's to You, Rachel Robinson", 'AU6DIIDZK2OQM', 2.0),
#  ('Kim', 'A3NCKDPCAUOD4T', 5.0),
#  ('Awaken The Giant Within (CD)', 'A1CDNTB7377YH2', 5.0),
#  ('We Were the Mulvaneys (A William Abrahams Book)', 'A2IIDELWB0IWRO', 5.0),
#  ('When Technology Fails: A Manual for Self Reliance & Planetary Survival',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ("Sultan's Snakes", 'A1MC6BFHWY6WC3', 5.0),
#  ('Death of Vishnu, the', 'A328S9RN3U5M68', 5.0),
#  ('The city of Gold and Lead', 'A22B13EJTZKCTM', 5.0),
#  ('Tarnsman of Gor (Chronicles of Counter-Earth)', 'A2NJO6YE954DBH', 4.0),
#  ('Stone Cribs', 'AXW1O6Q92XF0Z', 4.0),
#  ('The Conspiracy Club', 'A2F6N60Z96CAJI', 5.0),
#  ("It's Disgusting and We Ate It! True Food Facts from Around the World and Throughout History",
#   'A2NJO6YE954DBH',
#   5.0),
#  ('Charlie and the Chocolate Factory', 'A370Z6I5GBWU44', 5.0),
#  ('To Kill a Mockingbird', 'A3IKBHODOTYYHM', 4.0),
#  ('Mothman Prophecies', 'AD0J5KK4WQXNS', 5.0),
#  ('Harvest the Fire', 'A1XJ64FBB2IRGT', 3.0),
#  ('Mr. Lucky: A Novel of High Stakes', 'A2F6N60Z96CAJI', 4.0),
#  ('The Picture of Dorian Gray', 'A22B13EJTZKCTM', 4.0),
#  ('Falling Awake', 'A2F6N60Z96CAJI', 4.0),
#  ('The double helix: A personal account of the discovery of the structure of DNA',
#   'AHD101501WCN1',
#   5.0),
#  ('The Naked and the Dead', 'A3QVAKVRAH657N', 2.0),
#  ('God Makes the Rivers To Flow: Sacred Literature of the World',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('In search of Scotland', 'A3AUL23GMCOP2A', 3.0),
#  ("King Solomon's Mines", 'A20EEWWSFMZ1PN', 5.0),
#  ('Green Hills of Africa', 'AHD101501WCN1', 4.0),
#  ('Shadower (Shielder Series, Book 2)', 'A2BZCHIDR5FTYA', 5.0),
#  ('N Is for Noose', 'A1IIX764GG3WNZ', 4.0),
#  ('Letters', 'AXQ8T2D9IT6UG', 5.0),
#  ("One Flew Over the Cuckoo's Nest", 'A3NH7PYU4AD5GA', 4.0),
#  ("A Connecticut Yankee in King Arthur's Court", 'AJDYDG7YZY9QL', 5.0),
#  ('They Stand Together: The Letters of C.S. Lewis to Arthur Greeves (1914-1963)',
#   'AGHIV0V0ON7MO',
#   5.0),
#  ("The Origin of Species (Oxford World's Classics)", 'ALDRY40BPNY09', 2.0),
#  ('The Jordan Rules', 'A9Q28YTLYREO7', 5.0),
#  ('Pride and Prejudice', 'A1D2C0WDCSHUWZ', 5.0),
#  ('Beneath a Marble Sky: A Novel of the Taj Mahal', 'AFVQZQ8PW0L', 5.0),
#  ('Persuasion', 'A1D2C0WDCSHUWZ', 5.0),
#  ('SPOKEN HERE', 'AJDYDG7YZY9QL', 5.0),
#  ('London Bridges', 'A1M4NJYP0WNL8Q', 2.0),
#  ('Hostage', 'A2DSXA1E02C86D', 5.0),
#  ('Leviathan;: Or, The matter, forme and power of a commonwealth, ecclesiasticall and civil (Collier classics in the history of thought)',
#   'AHEU0PXUZ4VA8',
#   1.0),
#  ('The Hobbit', 'A1D2C0WDCSHUWZ', 5.0),
#  ('The Moon Is a Harsh Mistress', 'AF3X7J0XC391L', 5.0),
#  ('The Mysterious Island (Classics Illustrated)', 'A3DF7LMEQOND63', 5.0),
#  ('Magic Kingdom for Sale - Sold! (Landover Series)', 'A1I2O9Y3X3HXLS', 5.0),
#  ('To Kill a Mockingbird', 'A359U0JFFZ0Q04', 5.0),
#  ('Jonathan Strange & Mr. Norrell', 'AV74NYPSKHXBU', 5.0),
#  ('An inquiry into the nature and causes of the wealth of nations',
#   'A3MAN5CBRX1KEV',
#   4.0),
#  ('Angel Angel', 'A3M174IC0VXOS2', 4.0),
#  ('Death in Venice and Seven Other Stories', 'A258HDMERSI6WJ', 5.0),
#  ('The Battle for God', 'A2Z4KA3EFQWZOX', 3.0),
#  ('Major Bible Themes', 'A633NIAR4JJAR', 5.0),
#  ('Silas Marner', 'A3EJWHGO91FA0N', 5.0),
#  ('The Princess Bride', 'A28WJUJF6D2ULA', 5.0),
#  ("Sir John Magill's last journey;: An Inspector French case,",
#   'A3EJWHGO91FA0N',
#   4.0),
#  ('Fahrenheit 451', 'A12A08OL0TZY0W', 5.0),
#  ('Heaven on Earth: The Rise and Fall of Socialism', 'AUHG8KSHI529U', 5.0),
#  ('The Way of All Flesh (The Shrewsbury Edition of the Works of Samuel Butler: Classic Books- English Authors Ser. Vol. 17)',
#   'A368INKWDUYHMK',
#   5.0),
#  ('Why Courage Matters: The Way to a Braver Life', 'A1K1JW1C5CUSUZ', 4.0),
#  ("The Razor's Edge: A Novel", 'A20IIR0422G3A5', 4.0),
#  ('Learning From the Tanya: Volume Two in the Definitive Commentary on the Moral and Mystical Teachings of a Classic Work of Kabbalah',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Forerunner of the Charismatic Movement: The Life of Edward Irving',
#   'A1IBC9XP2LICQL',
#   5.0),
#  ('What Matters Most: How a Small Group of Pioneers Is Teaching Social Responsibility to Big Business, and Why Big Business Is Listening',
#   'A1NATT3PN24QWY',
#   5.0),
#  ("The French revolution: A history (The world's classics)",
#   'AQ3540NJNST0C',
#   1.0),
#  ('Gift from the sea (Signet books)', 'A3SN9EF7GTNEU2', 5.0),
#  ('The Scarlet Letter, A Romance', 'A3FVAWZNKW9GX', 5.0),
#  ("God's trombones: Seven Negro sermons in verse", 'A21VR7M8O55EF6', 5.0),
#  ('Oh My Stars', 'A1BI8PUEHA5CHW', 5.0),
#  ('Hard Facts, Dangerous Half-Truths And Total Nonsense: Profiting From Evidence-Based Management',
#   'A22RY8N8CNDF3A',
#   5.0),
#  ('O Pioneers! (Lrs Large Print Heritage Series)', 'A2YF4ZMECJVLK9', 5.0),
#  ("Absalom, Absalom!: The Questioning of Fictions (Twayne's Masterwork Studies) (No 76)",
#   'A16BJ43Z46QS3N',
#   4.0),
#  ('The Fellowship of the Ring', 'ADY0QI5IENSLY', 5.0),
#  ('The Beautiful and the Damned', 'A2N3YAM4K3ATM', 3.0),
#  ('Little women, or, Meg, Jo, Beth, and Amy', 'A2EDZH51XHFA9B', 1.0),
#  ('Political Ideals: Five essays on the individual and society',
#   'A36K2N527TXXJN',
#   3.0),
#  ('The Grapes of Wrath (Steinbeck Essentials)', 'A3BH49ZKESHDID', 5.0),
#  ("Sharpe's Eagle: Richard Sharpe and the Talavara Campaign, July 1809 (Richard Sharpe Adventure Series)",
#   'A2GBJQ9THOYDAJ',
#   5.0),
#  ('Founding Brothers: The Revolutionary Generation', 'A1K1JW1C5CUSUZ', 4.0),
#  ('Chasing A Blond Moon: A Woods Cop Mystery', 'A9LAPV8XNKZVZ', 3.0),
#  ('Foundation and Empire', 'A3DF7LMEQOND63', 4.0),
#  ('The Count of Monte Cristo: Golden Picture Classic', 'A3DF7LMEQOND63', 5.0),
#  ('The Garden of Eden, A Novel', 'A3TEH90X39WC8F', 4.0),
#  ('Gods and Androids', 'A1I2O9Y3X3HXLS', 5.0),
#  ('A Tale of Two Cities - Literary Touchstone Edition', 'A2O9HU1K7TCF7B', 5.0),
#  ('Small Boat Building', 'A14OJS0VWMOSWO', 5.0),
#  ('Chronicle Of America: American Revolution, 1700-1800',
#   'A2NJO6YE954DBH',
#   5.0),
#  ('Three Junes', 'A328S9RN3U5M68', 5.0),
#  ('Moby Dick;: Or, The white whale (A Signet classic)', 'A3FVAWZNKW9GX', 5.0),
#  ('The star fox', 'A1XJ64FBB2IRGT', 4.0),
#  ("Humboldt's gift (The 100 greatest masterpieces of American literature)",
#   'AHXAPVSHPJ6OJ',
#   5.0),
#  ('Preliminary analysis of wind data from the Oak Ridge site survey (NOAA technical memorandum ERL ARL)',
#   'A9LAPV8XNKZVZ',
#   3.0),
#  ('The HP Way: How Bill Hewlett and I Built Our Company',
#   'A1S3C5OFU508P3',
#   5.0),
#  ('The unpleasantness at the Bellona Club', 'A3EJWHGO91FA0N', 4.0),
#  ("Let's Eat: What Children Eat Around the World", 'A14OJS0VWMOSWO', 5.0),
#  ('Politically Correct Bedtime Stories: Modern Tales for Our Life and Times',
#   'A3QVAKVRAH657N',
#   4.0),
#  ('Leadership on the Line: Staying Alive through the Dangers of Leading',
#   'A3MAN5CBRX1KEV',
#   5.0),
#  ('Perelandra: A Novel', 'AUM3YMZ0YRJE0', 5.0),
#  ('Pay the Devil', 'AK7D1BHZOSOL1', 5.0),
#  ("Wouldn't Take Nothing For My Journey Now (Turtleback School & Library Binding Edition)",
#   'A3QZCA4LTTVGAD',
#   4.0),
#  ('Brave New World', 'A1I6ZXLKEUKV7W', 5.0),
#  ('In the Country of My Dreams', 'A14OJS0VWMOSWO', 5.0),
#  ('The Truth Is... My Life in Love and Music', 'A3SN9EF7GTNEU2', 5.0),
#  ('Slavery in the Islamic Middle East', 'A14OJS0VWMOSWO', 5.0),
#  ('Long Walk to Freedom.', 'A30KEXFT9SILL6', 5.0),
#  ('Pride & Prejudice (Penguin Classics)', 'A2ENIQZX6VJYUM', 5.0),
#  ('Playboy Adult Magazine:February 2003', 'A1CGLIDN7E5MK8', 5.0),
#  ('Shalimar the Clown: A Novel', 'A319KYEIAZ3SON', 4.0),
#  ('Down Under: Complete & Unabridged', 'A9I40WFF40R4', 5.0),
#  ('The Burnished Blade', 'A2GBJQ9THOYDAJ', 4.0),
#  ("Tess of the D'urbervilles (Summer Classics)", 'A1RLYOPK16YXC1', 4.0),
#  ('The Mayor of Casterbridge', 'A29NUB3P6YIWZG', 3.0),
# ...
#   'A3SN9EF7GTNEU2',
#   5.0),
#  ('Captains Courageous', 'A3RP1I0SL7091Q', 5.0),
#  ('Hop on Pop (I Can Read It All by Myself Beginner Books (Prebound))',
#   'A1X8VZWTOG8IS6',
#   3.0),
#  ('The Perricone Promise: Look Younger, Live Longer in Three Easy Steps',
#   'A24505CR98NLLV',
#   5.0),
#  ('Farewell, my lovely', 'A29NUB3P6YIWZG', 3.0),
#  ('Disgrace: Complete & Unabridged', 'A4R8GJX3UZ1I', 5.0),
#  ('Night', 'AIWDJ3S85O10Q', 5.0),
#  ('An Outcast of the Islands', 'A2I3D2NX4XKZYJ', 3.0),
#  ('The Moon Is a Harsh Mistress', 'A1EKTLUL24HDG8', 5.0),
#  ('Of Men and of Angels (Galway Chronicles, Book 2)', 'A1CIW2OEVAJRM2', 5.0),
#  ("Harry Potter and The Sorcerer's Stone", 'AMX0PJKV4PPNJ', 5.0),
#  ('The natural', 'AQQLWCMRNDFGI', 5.0),
#  ('Snowflakes for all Seasons', 'A281NPSIMI1C2R', 5.0),
#  ('The Wounded Land: Book 1 of "the Second Chronicles of Thomas Covenant"',
#   'A1X8VZWTOG8IS6',
#   4.0),
#  ("David's Secret Demons: Messiah, Murderer, Traitor, King (Bible in Its World)",
#   'A2F3M93RRLFQNJ',
#   3.0),
#  ('The Lion, the Witch and the Wardrobe Movie Tie-in Edition (The Chronicles of Narnia)',
#   'A10T0OW97SFBB',
#   5.0),
#  ('Five Star First Edition Mystery - Death Of A Prince', 'AFVQZQ8PW0L', 5.0),
#  ('The Adventures of Huckleberry Finn', 'A1EKTLUL24HDG8', 5.0),
#  ('And There Was Light...Autobiography Of Jacques Lusseyran...Blind Hero Of The French Resistance...Second Edition,Revised 2005',
#   'AF3X7J0XC391L',
#   5.0),
#  ('The Princess Bride', 'A2F3M93RRLFQNJ', 5.0),
#  ('Death in the Afternoon', 'A29LGHDM4PTVOA', 5.0),
#  ('Smoky Night (Caldecott Medal Book)', 'A13G1TKIKHGV3F', 1.0),
#  ('Hogfather (Discworld)', 'A2BT578J4IZOK6', 5.0),
#  ('The Evolution-Creation Struggle', 'AJDYDG7YZY9QL', 4.0),
#  ("The Gardener's Guide to Growing Daylilies", 'A14OJS0VWMOSWO', 5.0),
#  ('The Cancer Ward', 'A55MRYPUAX4QU', 5.0),
#  ('Pride & Prejudice (New Windmill)', 'A1D2C0WDCSHUWZ', 5.0),
#  ('The Thirteen Problems', 'A1BXA3SM3AJOKL', 5.0),
#  ('Dead Time', 'A3AY3EV2MFRFGG', 2.0),
#  ('Oh, the Things I Know!', 'A2HM0BZWQRV1EF', 4.0),
#  ('Antic Hay', 'ASOJUBRHQI1DW', 3.0),
#  ('Home Management 101: A Guide for Busy Parents', 'A281NPSIMI1C2R', 5.0),
#  ('Little Women', 'A1D2C0WDCSHUWZ', 5.0),
#  ('The Oxford companion to English literature', 'A2VE83MZF98ITY', 5.0),
#  ('BEYOND BELIEF (The Secret Gospel 0f Thomas)', 'A7UMC95YCRGTS', 5.0),
#  ('The Rolling Stones (Ace SF #73440)', 'AWLFVCT9128JV', 4.0),
#  ('A Year in Provence', 'A2YXRT2XIJIO57', 5.0),
#  ('Anne of Windy Poplars', 'A2TXR85WQLE32N', 5.0),
#  ('How to Be an Effective Manager: A Basic Guide to Maximizing Employee Morale, Motivation, and Productivity',
#   'A1S3C5OFU508P3',
#   4.0),
#  ('Quo Vadis, A Narrative of the Time of Nero', 'A3NCKDPCAUOD4T', 5.0),
#  ('The Human Comedy', 'A1MJMYLRTZ76ZX', 5.0),
#  ('Seek', 'AMX0PJKV4PPNJ', 5.0),
#  ('The Suspect (Crime, Penguin)', 'A370T7ZOJJ76I2', 4.0),
#  ('Majipoor chronicles', 'A2NBOL825B93OM', 5.0),
#  ('Appointment With Death.', 'A1BA72K4VK1UN1', 5.0),
#  ('The House on the Strand.', 'A2FNM5JVHZP0IW', 5.0),
#  ('The Adventures of Huckleberry Finn (Courage Literary Classics)',
#   'A1NPNGWBVD9AK3',
#   5.0),
#  ('Prince Caspian (Chronicles of Narnia, 2)', 'A3T0OTH5072YRE', 4.0),
#  ("Ahab's Wife: Or, the Star-Gazer", 'A1IU7S4HCK1XK0', 5.0),
#  ('The history of Troilus and Cressida (Signet classics, CD172. The Signet classic Shakespeare)',
#   'A6FIAB28IS79',
#   5.0),
#  ('King of the Wind', 'A14OJS0VWMOSWO', 5.0),
#  ('My Dream Of You', 'A319KYEIAZ3SON', 4.0),
#  ('The Great Gatsby', 'AAIL33CYCT47J', 5.0),
#  ('The Scarlet Letter : A Romance', 'A1K1JW1C5CUSUZ', 5.0),
#  ('A Princess of Mars', 'A20EEWWSFMZ1PN', 5.0),
#  ('Banner in the Sky', 'A2O5RT4RCC4NU2', 5.0),
#  ('We Wish to Inform You that Tomorrow We Will Be Killed with our Families',
#   'A133ZC2Z8MAIED',
#   5.0),
#  ('Brave New World', 'A20VXF9DYI0I6H', 3.0),
#  ('The poisonwood Bible : a novel', 'A39NS429FYXAD1', 5.0),
#  ('Count of Monte Cristo', 'A2H1W8V6R9TJ9E', 5.0),
#  ('Animal Husbandry', 'A1BI8PUEHA5CHW', 3.0),
#  ('The 1960s (Decades of the 20th Century)', 'A16QODENBJVUI1', 5.0),
#  ('Piece of Work', 'AFVQZQ8PW0L', 5.0),
#  ('THE CATCHER IN THE RYE', 'A29NUB3P6YIWZG', 5.0),
#  ('The Adventures of Huckleberry Finn', 'A1NC9AGZOBI0M1', 4.0),
#  ('Ask the Awakened: The Negative Way', 'A14OJS0VWMOSWO', 5.0),
#  ('Down Came the Rain: My Journey Through Postpartum Depression',
#   'A2F3SXHT6RBV81',
#   3.0),
#  ("Alice's Adventures in Wonderland (Aladdin Classics)",
#   'A3H82LUT1EC655',
#   5.0),
#  ("Uncle Tom's Children", 'A3OJFPKMCXKOM0', 4.0),
#  ('Words of Wisdom from the Dalai Lama: Quotes by His Holiness',
#   'AIJ6XU28MF3B',
#   4.0),
#  ('1001 Ways To Reward Employees', 'A1IU7S4HCK1XK0', 5.0),
#  ('Last Man Standing', 'A3OJAWIMUKNHTP', 5.0),
#  ('Bad Dirt', 'A1NC9AGZOBI0M1', 5.0),
#  ('I Will Never Not Ever Eat a Tomato (Charlie and Lola)',
#   'A6HXFDIC7DVTC',
#   4.0),
#  ('Alice in Wonderland', 'A2BT578J4IZOK6', 4.0),
#  ('China Today: How Population Control, Human Rights, Government Repression, Hong Kong, and Democratic Reform Affect Life in China and Will Shape World',
#   'A24505CR98NLLV',
#   5.0),
#  ('The Quiet American', 'A2RPIGO3G4M6GN', 2.0),
#  ('Three Nights in August: Strategy, Heartbreak, and Joy: Inside the Mind of a Manager',
#   'A30TK6U7DNS82R',
#   5.0),
#  ('Lonesome Dove', 'A1E2NA2F4RTQ9B', 5.0),
#  ('ASKING FOR TROUBLE', 'A1D5RCOILPC9LX', 3.0),
#  ("Angelina's Birthday", 'A1POFVVXUZR3IQ', 5.0),
#  ('Little Women: or Meg, Jo, Beth, and Amy', 'A19XE6G6NDZFPS', 5.0),
#  ('Neverwhere', 'A3DXVYD2TQHWGD', 3.0),
#  ('Pride & Prejudice (Penguin Classics)', 'AQCQ5F0OJXMG9', 5.0),
#  ("HUXLEY: FROM DEVIL'S DISCIPLE TO EVOLUTION'S HIGH PRIEST.",
#   'A3GK9LT41X73NC',
#   5.0),
#  ('Blood meridian, or, The evening redness in the west (Picador)',
#   'A359U0JFFZ0Q04',
#   4.0),
#  ('Leaves of Grass', 'AHD101501WCN1', 4.0),
#  ('The Picture of Dorian Gray (Bantam Classics)', 'A1G9FX1KV45N41', 5.0),
#  ('O is for Outlaw: A Kinsey Millhone Mystery', 'A11M98R135HMSY', 5.0),
#  ('Silas Marner (The Classic Collection)', 'A2M7RPFEMKRT8M', 4.0),
#  ('Myths, Lies, and Downright Stupidity: Get Out the Shovel -- Why Everything You Know is Wrong',
#   'A22RY8N8CNDF3A',
#   2.0),
#  ('We Have Always Lived In The Castle', 'ACIBQ6BQ6AWEV', 5.0),
#  ('Barnaby Rudge (Library of classics)', 'A1G37DFO8MQW0M', 5.0),
#  ('The Moon Is a Harsh Mistress', 'A1Z81GM85KH5XS', 4.0),
#  ('Ulysses (International Collectors Library)', 'A3NI29U4P5NQF1', 5.0),
#  ('House of Mirth', 'A319KYEIAZ3SON', 5.0),
#  ('BLUES FOR MISTER CHARLIE', 'AGEIT17HENDIS', 5.0),
#  ('Woman in White', 'AT2R7ZVT7QYOU', 3.0),
#  ('In Search of Dracula: The History of Dracula and Vampires',
#   'ABMX8XUNPR3LP',
#   2.0),
#  ("Cat's Cradle", 'A2I3D2NX4XKZYJ', 4.0),
#  ("Jannaway's Mutiny", 'A14OJS0VWMOSWO', 5.0),
#  ('Trivia for Smarties', 'A14OJS0VWMOSWO', 5.0),
#  ('Swim with the Dolphins: How Women Can Succeed in Corporate America on Their Own Terms',
#   'A26JGAM6GZMM4V',
#   5.0),
#  ('Wuthering Heights (Signet classics)', 'A3QN1SJPR6L552', 4.0),
#  ('Tropical Freeze', 'A1M4NJYP0WNL8Q', 5.0),
#  ('Brave New World', 'A2L7N2U5Z316ZE', 5.0),
#  ("We'll Always Have Parrots (Meg Langslow Mysteries)", 'A3V6Z4RCDGRC44', 5.0),
#  ('White Bread Competition', 'A3OJAWIMUKNHTP', 5.0),
#  ('The New Science of Technical Analysis: Using the Statistical Techniques of Neuroscience to Uncover Order and Chaos in the Markets',
#   'A3EQQP0LD4Z375',
#   4.0),
#  ('A Modern Instance.', 'A1TIZI060W4BD9', 4.0),
#  ('Memoirs of a Geisha (Signed)', 'A23GFTVIETX7DS', 5.0),
#  ('Owl at Home (An I CAN READ Book)', 'A2EDZH51XHFA9B', 4.0),
#  ('The first part of King Henry the Fourth (The Pelican Shakespeare)',
#   'A3EOHYIHQM3KK',
#   4.0),
#  ('Nights of Rain and Stars', 'A3BIWTN2DA0YY2', 3.0),
#  ('I, The Jury', 'A29NUB3P6YIWZG', 4.0),
#  ('Age of Conan: Songs of Victory: Legends of Kern, Volume IIl',
#   'AFVQZQ8PW0L',
#   4.0),
#  ("Persuasion (World's Classics)", 'A3O2RCKAMSE9X7', 5.0),
#  ('Melville in the South Pacific (North Star Books #22)',
#   'A1S3C5OFU508P3',
#   4.0),
#  ("Evolution's Rainbow: Diversity, Gender, and Sexuality in Nature and People",
#   'A1DK5AZMXS1QA3',
#   3.0),
#  ('Invasion of Other Gods', 'A2OJW07GQRNJUT', 5.0),
#  ('Low Red Moon', 'A2EDZH51XHFA9B', 4.0),
#  ('Lord of Light', 'AFVQZQ8PW0L', 5.0),
#  ('Vanish', 'A2DSXA1E02C86D', 3.0),
#  ("Evolution's Captain: The Dark Fate of the Man Who Sailed Charles Darwin Around the World",
#   'A2MF2QVSCUI27G',
#   4.0),
#  ("Appleby's Other Story", 'A13OFOB1394G31', 5.0),
#  ('Animal Farm (Signet Classics, CT304)', 'A1S3C5OFU508P3', 5.0),
#  ('Jill (New Portway Books)', 'AT2R7ZVT7QYOU', 4.0),
#  ('the Sword and the Stone', 'A1POFVVXUZR3IQ', 5.0),
#  ('The long farewell, (Red badge detective)', 'A13OFOB1394G31', 5.0),
#  ('How Great Generals Win', 'A3NIQK6ZLYEP1L', 5.0),
#  ('Fantastic Food with Splenda: 160 Great Recipes for Meals Low in Sugar, Carbohydrates, Fat, and Calories',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Sense & Sensibility Cds (Penguin Classics)', 'A2UIXU97JYCPZG', 5.0),
#  ('Norway 1940 (World War II)', 'A133ZC2Z8MAIED', 3.0),
#  ('Appointment with Death', 'A1NC9AGZOBI0M1', 5.0),
#  ('Anthem', 'A1S3C5OFU508P3', 5.0),
#  ('On Job: God-Talk and the Suffering of the Innocent', 'A2CW9IQAPFEYLM', 5.0),
#  ('Customer Astonishment: 10 Secrets to World-Class Customer Care',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('The Diamond Throne Book One of the Elenium', 'A1M4NJYP0WNL8Q', 4.0),
#  ('The Finishing School', 'A2F6N60Z96CAJI', 4.0),
#  ('Penthouse Adult Magazine:April 2003', 'A1CGLIDN7E5MK8', 5.0),
#  ('The Blackwell Companion to Christian Ethics (Blackwell Companions to Religion)',
#   'A20IIR0422G3A5',
#   4.0),
#  ('Walden', 'A2N3YAM4K3ATM', 3.0),
#  ("Love's Executioner, And Other Tales Of Psychotherapy",
#   'A2FQWV725FGE8S',
#   5.0),
#  ('How to Win Friends & Influence People', 'A1CDNTB7377YH2', 5.0),
#  ('Facing the Wind: A True Story of Tragedy and Reconciliation',
#   'A1ER5AYS3FQ9O3',
#   5.0),
#  ('American freedom and Catholic power', 'A3C0380R9NMLHD', 2.0),
#  ('Letters to Kelly (Silhouette Intimate Moments No. 1213)',
#   'ANOBZWKE25SBY',
#   2.0),
#  ('Menard\'s in Louisiana: (Maynard, Meynard, Minard, Meynier), Broussard, Conques, Dore, Duhon, Elkins, Mouton, 1675-1992 : (a "family genealogy tree" of ... from France to south central Louisiana, USA',
#   'A1I6ZXLKEUKV7W',
#   4.0),
#  ('The Reader', 'A2IIDELWB0IWRO', 4.0),
#  ('The Red Tent (Bestselling Backlist)', 'AYT4FJYVCHYLE', 5.0),
#  ("The Epicure's Lament", 'A2F6N60Z96CAJI', 4.0),
#  ('Saving Joe', 'A13F2IV3ME23R', 5.0),
#  ('A Room with a View', 'A1XTWXIMUCDGQE', 5.0),
#  ('Breaking Point (Troubleshooters, Book 9)', 'AFVQZQ8PW0L', 5.0),
#  ("A Connecticut Yankee in King Arthur's Court", 'A1LMBM1N4EXS5W', 4.0),
#  ('Breakthrough On Skis: How to Get Out of the Intermediate Rut',
#   'A3V6Z4RCDGRC44',
#   5.0),
#  ('To kill a mockingbird', 'A13E0ARAXI6KJW', 5.0),
#  ('Biblical Exegesis in the Apostolic Period', 'AF3X7J0XC391L', 5.0),
#  ('WALDO AND MAGIC, INC. - Two way-out short novels', 'A1EKTLUL24HDG8', 3.0),
#  ('Chinese Language; Fact and Fantasy', 'A1OB5L3WMHJAD9', 4.0),
#  ('The Pearl of the Soul of the World (Darkangel Trilogy)',
#   'A1DW4U1LQV0XW7',
#   5.0),
#  ('The Book of Enoch', 'A3UDYY6L2NH3JS', 5.0),
#  ('Buddhist Psychology', 'A2HQ8RTAJYEUJO', 3.0),
#  ("The Hitchhiker's Guide to the Galaxy", 'A18OBUSMXVE8R0', 5.0),
#  ('Pirate (Hawke Series)', 'A11B61QBGHLQDN', 2.0),
#  ('Education of a wandering man', 'A1BMKEJ61X57EU', 4.0),
#  ("I'm Watching You (Warner Forever)", 'ANOBZWKE25SBY', 4.0),
#  ('The Postman Always Rings Twice', 'A3QVAKVRAH657N', 5.0),
#  ('While You Slept', 'A3AUL23GMCOP2A', 5.0),
#  ('Mapping Cyberspace', 'AG35NEEFCMQVR', 4.0),
#  ('The Early Germans', 'A2GBJQ9THOYDAJ', 3.0),
#  ('The Sex Chronicles: Shattering the Myth', 'A3FHAMLNGHCFU7', 3.0),
#  ('On the Road', 'ACIBQ6BQ6AWEV', 4.0),
#  ('Green Eggs and Ham (Living Books Interactive Animated Stories)',
#   'A1PXH6NS60C8V5',
#   5.0),
#  ('Memory in Death (In Death #22)', 'A2F6N60Z96CAJI', 4.0),
#  ('What Maisie knew (Doubleday anchor books)', 'A2ENIQZX6VJYUM', 4.0),
#  ('The Sign of the Four', 'A1EKTLUL24HDG8', 5.0),
#  ('The Incredible Journey', 'AEKWD5WIFP6', 5.0),
#  ('The Forgotten Man (SIGNED)', 'A3M174IC0VXOS2', 4.0),
#  ('The Tortilla Curtain', 'A3QVAKVRAH657N', 3.0),
#  ('Wild Bells to the Wild Sky', 'A2F540P3L6P5CL', 4.0),
#  ('Charlie and the Chocolate Factory:A Play', 'A370Z6I5GBWU44', 5.0),
#  ('Gone', 'A2FNM5JVHZP0IW', 5.0),
#  ('The Great Hunt (Turtleback School & Library Binding Edition) (The Wheel of Time, Book 2)',
#   'A3DF7LMEQOND63',
#   4.0),
#  ('The Adventures of Robinson Crusoe', 'A2CW9IQAPFEYLM', 5.0),
#  ('Woman of Contradictions: The Life of George Eliot', 'A3SOV9HFM5H9T1', 3.0),
#  ('Hamlet', 'A20EEWWSFMZ1PN', 5.0),
#  ('Multicultural Literature for Children and Young Adults: Reflections on Critical Issues',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('Whistling Season, a Novel', 'A1D5RCOILPC9LX', 4.0),
#  ('The Hiding Place', 'A3Q04XXGGED746', 5.0),
#  ('Year of Wonders (Turtleback School & Library Binding Edition)',
#   'A30ZPSYOGFJXR6',
#   4.0),
#  ('The assistant', 'A29SHFBU5O9BWO', 3.0),
#  ('Mystery of the Blue Train', 'A4FX5YCJA630V', 3.0),
#  ('Sung in Blood', 'A1I2O9Y3X3HXLS', 4.0),
#  ('On Liberty', 'A23ZCJ9U3ZN0FK', 5.0),
#  ('The Stars Are Ours (Vintage Ace SF F-207)', 'A1I2O9Y3X3HXLS', 5.0),
#  ('A Stranger In My Own House: The Story Of W. E. B. Du Bois (Portraits of Black Americans)',
#   'A14OJS0VWMOSWO',
#   5.0),
#  ('The Tea-Olive Bird-Watching Society', 'AFVQZQ8PW0L', 5.0),
#  ('Johnny Cash At Folsom Prison: The Making Of A Masterpiece',
#   'AQE41QO3NEUMW',
#   4.0),
#  ('Winter', 'A2XRMQA6PJ5ZJ8', 5.0),
#  ('Women and Ghosts', 'A32VWSQ0FPZKZ3', 1.0),
#  ('The Disappearance of Sherlock Holmes (Sherlock Holmes Mysteries (Penguin))',
#   'A2CR57GAJKNWVV',
#   3.0),
#  ('Hawaii The Big Island Revealed: The Ultimate Guidebook',
#   'A3V6Z4RCDGRC44',
#   5.0),
#  ('Paradise Lost (Odyssey Series in Literature)', 'A3NI29U4P5NQF1', 5.0),
#  ('The Catcher in the Rye [Audiobook] [Cd] [Unabridged] (Audio CD)',
#   'A3RINLIDX74QLP',
#   4.0),
#  ("Howl's Moving Castle", 'A1BXA3SM3AJOKL', 5.0),
#  ('Amateur Marriage', 'A1K1JW1C5CUSUZ', 5.0),
#  ('To Kill a Mockingbird', 'A20EEWWSFMZ1PN', 5.0),
#  ('How People Harness Their Collective Wisdom And Power to Construct the Future (Research in Public Management (Unnumbered).)',
#   'A1S8AJIUIO6M9K',
#   5.0),
#  ('Atlas Shrugged', 'A22RY8N8CNDF3A', 4.0),
#  ('The Princess Bride', 'ABMX8XUNPR3LP', 4.0),
#  ('The Terminal Man.', 'A1IBC9XP2LICQL', 4.0),
#  ("4th of July (Women's Murder Club)", 'A2RPIGO3G4M6GN', 3.0),
#  ('Crazy Colour PRINCE2 Process Map', 'A2NYK9KWFMJV4Y', 5.0),
#  ("Alice's adventures in wonderland: And Through the looking-glass, and what Alice found there,",
#   'A2KBF2OYR359AJ',
#   3.0),
#  ('The Great Santini', 'A33EVEMS61JYRQ', 4.0),
#  ("Give 'em the ax", 'A3MV1KKHX51FYT', 5.0),
#  ("Angela's Ashes (Turtleback School & Library Binding Edition)",
#   'A5HVPX1ETWWIV',
#   5.0),
#  ('Lost World', 'A3C0380R9NMLHD', 4.0),
#  ('The Cat Who Went to Paris', 'A3SN9EF7GTNEU2', 5.0),
#  ('And then there were none', 'AHUT55E980RDR', 5.0),
#  ('This Side of Paradise', 'A3LKWMM12AF0PU', 5.0),
#  ("Sharpe's Havoc: Book VII of the Sharpe Series", 'A3BH49ZKESHDID', 4.0),
#  ('Prep', 'A1LKSZ9CYJ6829', 5.0),
#  ('The King David Report (European Classics)', 'A12A08OL0TZY0W', 5.0),
#  ('The Notebook', 'A25HYPL2XKQPZB', 1.0),
#  ('HR GIGER ARh+', 'AUTBHG6070SL4', 5.0),
#  ('Don Camillo Takes The Devil By The Tail.', 'A1JTG5X4VHJV27', 4.0),
#  ('The Proper Care of Labrador Retrievers', 'ALR35EFI69S5R', 4.0),
#  ('The Lion, the Witch and the Wardrobe: A Story for Children',
#   'AWLFVCT9128JV',
#   4.0),
#  ('Ever Since Darwin: Reflections in Natural History', 'AXSH6O4OP5L4M', 5.0),
#  ('THE MURDER OF ROGER ACKROYD', 'A2AYSFGUP5VTY3', 4.0),
#  ('Resilience: How to Bounce Back When the Going Gets Tough!',
#   'A2VP7JOT3K7PFM',
#   5.0),
#  ('The effect of a rating change on commercial paper outstandings (Finance and economics discussion series)',
#   'A370Z6I5GBWU44',
#   4.0),
#  ('A Year in Provence', 'A1NPNGWBVD9AK3', 5.0),
#  ('Fishing for a Major (Students Helping Students Series)',
#   'A1ER5AYS3FQ9O3',
#   5.0),
#  ('Brave new world,: A novel', 'AK0CENM3LUM28', 4.0),
#  ('Two Brothers [2 BROTHERS] [Mass Market Paperback]', 'AFVQZQ8PW0L', 5.0),
#  ('Dracula (G. K. Hall (Large Print))', 'A1D2C0WDCSHUWZ', 5.0),
#  ...]

# %%
from collections import defaultdict

def get_top_n(predictions, n=10):
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
from surprise import accuracy

print('**Fitting the train data...**')
svd.fit(trainset)       

print('**Predicting the test data...**')
pred_test = svd.test(testset)

rmse = round(accuracy.rmse(pred_test), 3)
print('**RMSE for the predicted result is ' + str(rmse) + '**')   

top_n = get_top_n(pred_test)
recommenddf = pd.DataFrame(columns=['title', 'user', 'rating'])
for item in top_n:
    subdf = pd.DataFrame(top_n[item], columns=['user', 'rating'])
    subdf['title'] = item
    cols = subdf.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    subdf = subdf[cols]
    recommenddf = pd.concat([recommenddf, subdf], axis = 0)
# Out:
# **Fitting the train data...**
# **Predicting the test data...**
# RMSE: 0.7794
# **RMSE for the predicted result is 0.779**

# %%
recommenddf
# Out:
#                                                 title            user  \
# 0                                      Flying Colours  A3AYGXMH34R18Y
# 1                                      Flying Colours   AHHUNTFQGUGX8
# 2                                      Flying Colours  A1K1JW1C5CUSUZ
# 3                                      Flying Colours  A1LMBM1N4EXS5W
# 0                                  Lilies On The Moon  A14OJS0VWMOSWO
# ..                                                ...             ...
# 0   Mind, Matter and Quantum Mechanics (The Fronti...  A2OJW07GQRNJUT
# 0                The Koran Interpreted: A Translation  A2Z4KA3EFQWZOX
# 0   American Jezebel : The Uncommon Life of Anne H...  A2Z4KA3EFQWZOX
# 0   Buffy contre les vampires, tome 26 : La Tueuse...  A2NJO6YE954DBH
# 0   Another Vietnam: Pictures of the War from the ...  A2YXRT2XIJIO57
#
#       rating
# 0   4.699601
# 1   4.648454
# 2   4.588041
# 3   4.263654
# 0   4.800427
# ..       ...
# 0   4.747840
# 0   4.215260
# 0   4.262879
# 0   4.458985
# 0   4.497052
#
# [44190 rows x 3 columns]

# %%
from surprise.model_selection.validation import cross_validate
print('**Cross Validating the data...**')
cv_result = cross_validate(svd, ratings_Surprise_Data, n_jobs=-1)
cv_result = round(cv_result['test_rmse'].mean(),3)
print('**Mean CV RMSE is ' + str(cv_result)  + '**')
# Out:
# **Cross Validating the data...**
# **Mean CV RMSE is 0.777**

# %%
def recommend(user, n=5):
    print('**Recommending top ' + str(n)+ ' products for userid : ' + user + ' ...**')
    df = recommenddf[recommenddf['user'] == user].head(n)
    return df

# %%
result_svd_user1 = recommend(user='A3AYGXMH34R18Y', n=5)
result_svd_user1
# Out:
# **Recommending top 5 products for userid : A3AYGXMH34R18Y ...**
#                                         title            user    rating
# 0                              Flying Colours  A3AYGXMH34R18Y  4.699601
# 0  Travels With Charley, In Search of America  A3AYGXMH34R18Y  4.598884
# 6                                  The Plague  A3AYGXMH34R18Y  4.725475
# 3        Of Mice and Men (Penguin Audiobooks)  A3AYGXMH34R18Y  4.764790
# 4           Of Mice and Men Hb (New Windmill)  A3AYGXMH34R18Y  4.787625

# %%
result_svd_user2 = recommend(user='A1LMBM1N4EXS5W', n=5)
result_svd_user2
# Out:
# **Recommending top 5 products for userid : A1LMBM1N4EXS5W ...**
#                            title            user    rating
# 3                 Flying Colours  A1LMBM1N4EXS5W  4.263654
# 3             The Golden Compass  A1LMBM1N4EXS5W  4.339286
# 5  Kim (Modern Library Classics)  A1LMBM1N4EXS5W  4.068062
# 6  Kim (Modern Library Classics)  A1LMBM1N4EXS5W  4.068062
# 4                Rosemary's Baby  A1LMBM1N4EXS5W  3.676699

# %%
result_svd_user3 = recommend(user='A2YXRT2XIJIO57', n=5)
result_svd_user3
# Out:
# **Recommending top 5 products for userid : A2YXRT2XIJIO57 ...**
#                                        title            user    rating
# 0      A People's History of the Vietnam War  A2YXRT2XIJIO57  4.530493
# 3  Heart of Darkness. (Heritage Club Series)  A2YXRT2XIJIO57  4.418928
# 1                         THE SUN ALSO RISES  A2YXRT2XIJIO57  4.445930
# 2                                        Kim  A2YXRT2XIJIO57  4.227001
# 9    A Portrait of the Artist as a Young Man  A2YXRT2XIJIO57  4.476279
